# %% [markdown]
# # 12-2. 텍스트 데이터를 문자열로 저장한다는 것 (1) 인코딩과 디코딩

# %% [markdown]
# ### 텍스트 데이터를 문자열로 저장한다는 것

# %%
my_str = 'Welcome'
ur_str = "You're welcome"

print(my_str)
print(ur_str)

print(type(my_str))
print(type(ur_str))
# Out:
# Welcome
# You're welcome
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ### 인코딩과 디코딩

# %%
print(ord('가'))
# Out:
# 44032

# %%
str1 = b'hello'
str2 = 'hello'
str3 = u'hello'
print(type(str1),type(str2),type(str3))
# Out:
# <class 'bytes'> <class 'str'> <class 'str'>

# %% [markdown]
# # 12-3. 텍스트 데이터를 문자열로 저장한다는 것 (2) 문자열 다루기

# %% [markdown]
# ### 이스케이프 문자

# %%
s = 'I dont't like Python'
# Out:
#   File "<ipython-input-5-981c193e6265>", line 1
#     s = 'I dont't like Python'
#                 ^
# SyntaxError: invalid syntax

# %%
print("사회적\n거리두기")
print("사회적\t거리두기")
print('오늘부터\'사회적 거리두기\'')
# Out:
# 사회적
# 거리두기
# 사회적	거리두기
# 오늘부터'사회적 거리두기'

# %% [markdown]
# ### 원시 문자열

# %%
print("Please don\'t touch it")
print(r"Please don\'t touch it")
# Out:
# Please don't touch it
# Please don\'t touch it

# %% [markdown]
# ### startswith, endswith

# %%
EmployeeID = ['OB94382', 'OW34723', 'OB32308', 'OB83461', 
                                  'OB74830', 'OW37402', 'OW11235', 'OB82345'] 
Production_Employee = [P for P in EmployeeID if P.startswith('OB')]
Production_Employee
# Out:
# ['OB94382', 'OB32308', 'OB83461', 'OB74830', 'OB82345']

# %%
png = [png for png in photo if png.endswith('.png')]

# %% [markdown]
# ### 공백 문자 처리 : trimming

# %%
print("사회적 거리두기")
print('--------------------------')
print("사회적\t거리두기")
print('--------------------------')
print("사회적\n거리두기")
print('--------------------------')
print("사회적\r거리두기")
# Out:
# 사회적 거리두기
# --------------------------
# 사회적	거리두기
# --------------------------
# 사회적
# 거리두기
# --------------------------
# 거리두기

# %%
txt = "      .....Strip white spaces.      "
print('[{}]'.format(txt))
print('--------------------------')

#- 양쪽 공백 제거 : strip()
print('[{}]'.format(txt.strip()))
print('--------------------------')

#- 왼쪽 공백 제거 : lstrip()
print('[{}]'.format(txt.lstrip()))
print('--------------------------')

#- 오른쪽 공백 제거 : rstrip()
print('[{}]'.format(txt.rstrip()))
# Out:
# [      .....Strip white spaces.      ]
# --------------------------
# [      .....Strip white spaces.      ]
# --------------------------
# [      .....Strip white spaces.      ]
# --------------------------
# [      .....Strip white spaces.      ]

# %% [markdown]
# ### 대소문자 관련

# %%
txt = "I fell into AIFFEL"
txt.capitalize()
# Out:
# 'I fell into aiffel'

# %% [markdown]
# ### isX

# %%
print("aiffel".isupper()) # false
print("aiffel".islower())  #true
print("PYTHON".istitle()) #false
print("python101".isalpha()) #false
print("python101".isalnum()) #false -> true
print("101".isdecimal()) #true
# Out:
# False
# True
# False
# False
# True
# True

# %% [markdown]
# ### join()과 split()

# %%
stages = ['fundamentals','exploratioin','goingdeeper']

".".join(stages)

'fundamentals.exploratioin.goingdeeper'.split('.')
# Out:
# ['fundamentals', 'exploratioin', 'goingdeeper']

# %% [markdown]
# ### replace()

# %%
sent = 'I can do it!!'
sent.replace("I",'You')
# Out:
# 'You can do it!!'

# %% [markdown]
# ### 불변(immutable)의 문자열

# %%
sent = 'I fell into AIFFEL'
print(sent)
print(id(sent))
sent = sent.upper()
print(sent)
print(id(sent))

# %%
x = [1,2]
y= x

y.append(3)

print(x)
print(y)
# Out:
# [1, 2, 3]
# [1, 2, 3]

# %% [markdown]
# # 12-4. 텍스트 데이터를 문자열로 저장한다는 것 (3) 정규 표현식

# %% [markdown]
# ### 문자열 vs 정규 표현식

# %%
sent = "I can do it!!"
rep = sent.replace("I","You")
rep
# Out:
# 'You can do it!!'

# %%
import re

sent = "I can do it!!!"
pattern = re.sub("I","You",sent)
pattern
# Out:
# 'You can do it!!!'

# %% [markdown]
# ### 정규 표현식 시작하기

# %%
import re

#1단계
pattern = re.compile("the")

#2단계
pattern.findall('of the people, for the people, by the people')

#1단계 + 2단계
re.findall('the','of the people,for the people, by the people')
# Out:
# ['the', 'the', 'the']

# %% [markdown]
# ### 메서드

# %%
src = 'My name is'
regex = re.match("My",src)
print(regex)
if regex:
  print(regex.group())
else:
  print("No")
# Out:
# <re.Match object; span=(0, 2), match='My'>
# My

# %% [markdown]
# ### 패턴 : 특수문자, 메타 문자

# %%
text = """
The first season of America Premiere League  was played in 1993. 
The second season was played in 1995 in South Africa. 
Last season was played in 2019 and won by Chennai Super Kings (CSK).
CSK won the title in 2000 and 2002 as well.
Mumbai Indians (MI) has also won the title 3 times in 2013, 2015 and 2017.
"""

pattern = re.compile("[1-2]\d\d\d")
pattern.findall(text)
# Out:
# ['1993', '1995', '2019', '2000', '2002', '2013', '2015', '2017']

# %%
phoneNum = re.compile(r'\d\d\d-\d\d\d-\d\d\d\d')
phone = phoneNum.search("this is my phone number 010-9605-1138")
if phone:
  print(phone.group())
print("--------")
phone = phoneNum.match("this is my phone number 010-9605-1138")
if phone:
  print(phone.group())
# Out:
# --------

# %%
#- 전화번호(숫자, 기호)
phonenumber = re.compile(r'\d\d\d-\d\d\d-\d\d\d\d')
phone = phonenumber.search('This is my phone number 010-111-1111')
if phone:
  print(phone.group())
print('------')
phone = phonenumber.match ('This is my phone number 010-111-1111')
if phone:
  print(phone.group())
# Out:
# 010-111-1111
# ------

# %%
#- 전화번호(숫자, 기호)
phonenumber = re.compile(r'\d{3}-\d{3}-\d{4}')
phone = phonenumber.search('This is my phone number 010-111-1111')
if phone:
  print(phone.group())
print('------')
phone = phonenumber.match ('This is my phone number 010-111-1111')
if phone:
  print(phone.group())
# Out:
# 010-111-1111
# ------

# %%
#- 전화번호(숫자, 기호)
phonenumber = re.compile(r'(\d{3}-){2}\d{4}')
phone = phonenumber.search('This is my phone number 010-111-1111')
if phone:
  print(phone.group())
print('------')
phone = phonenumber.match ('This is my phone number 010-111-1111')
if phone:
  print(phone.group())
# Out:
# 010-111-1111
# ------

# %%
text = "My e-mail adress is doingharu@aiffel.com, and tomorrow@aiffel.com"


pattern = re.compile("[0-9a-zA-Z]+@[0-9a-z]+\.[0-9a-z]+")    #1회 이상 반복
pattern.findall(text)
# Out:
# ['doingharu@aiffel.com', 'tomorrow@aiffel.com']

# %% [markdown]
# # 12-5. 파일과 디렉터리 (1) 파일

# %% [markdown]
# ### 파일

# %%
f = open("hello.txt","w")

for i in range(10):
  f.write("안녕")

f.close()
print("완료!")
# Out:
# 완료!

# %%
with open("hello.txt","r") as f:
  print(f.read())
# Out:
# 안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕

# %%
quotes = ["\n안녕하세요.\n", "반갑습니다.\n", "오랜만입니다.\n"]

with open("hello.txt","a") as f:
  f.writelines(quotes)

with open("hello.txt","r") as f:
  result = f.readlines()
  print(result)
# Out:
# ['안녕안녕안녕안녕안녕안녕안녕안녕안녕안녕\n', '안녕하세요.\n', '반갑습니다.\n', '오랜만입니다.\n', '\n', '안녕하세요.\n', '반갑습니다.\n', '오랜만입니다.\n']

# %%
with open("hello.txt","r") as f:
  hello = f.readlines()
  print(f'위치: {f.tell()}')
  print("hello")
  print("---------")
  f.seek(10)
  print(f'위치: {f.tell()}')
# Out:
# 위치: 170
# hello
# ---------
# 위치: 10

# %% [markdown]
# # 12-7. 파일과 디렉터리 (3) 모듈과 패키지

# %% [markdown]
# ### 파이썬 파일은 어디에 저장될까?

# %%
import sys
import glob
import os

sys.executable
# Out:
# '/usr/bin/python3'

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.8/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
os.getcwd()
glob.glob('content')
# Out:
# []

# %% [markdown]
# # 12-8. 여러가지 파일 포맷 다루기 (1) CSV 파일

# %% [markdown]
# ### CSV

# %%
billboardchart = {
  				 1 : ["Tho Box","Roddy Ricch","2019-12-19"],
                 2 : ["Don't Start Now", "Dua Lipa", "2019-11-01"],
                 3 : ["Life Is Good", "Future Featuring Drake", "2020-02-10"],
                 4 : ["Blinding", "The Weeknd", "2019-11-29"],
                 5 : ["Circles", "Post Malone","2019-08-30"]}

with open("billboardchart.csv","w") as f:
  for i in billboardchart.values():
    data = ",".join(i)
    f.write(data+"\n")

# %% [markdown]
# #### 헤더 추가하기

# %%
import csv

header = ['title','singer','released date']

with open("billboardchar.csv","r") as inputfile:
  with open("billboardchart.csv","w",newline='\n') as outputfile:
    fi = csv.reader(inputfile,delimiter=',')
    fo = csv.writer(outputfile,delimiter=',')
    fo.writerow(header)
    for row in fi:
      fo.writerow(row)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-61-eb197889ce90> in <module>
#       3 header = ['title','singer','released date']
#       4
# ----> 5 with open("billboardchar.csv","r") as inputfile:
#       6   with open("billboardchart.csv","w",newline='\n') as outputfile:
#       7     fi = csv.reader(inputfile,delimiter=',')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'billboardchar.csv'
