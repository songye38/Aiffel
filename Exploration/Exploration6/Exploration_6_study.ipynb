# %%
# pandas 1.3.3
# numpy 1.21.4
# tensorflow 2.6.0
# keras 2.6.0 으로 설치 후 에러 없어짐.

# %%
sentence = '나는 밥을 먹었다.'

source_sentence='<start>'+sentence
target_sentence=sentence+'<end>'

print("Source 문장 : ",source_sentence)
print("Target 문장 : ",target_sentence)
# Out:
# Source 문장 :  <start>나는 밥을 먹었다.
# Target 문장 :  나는 밥을 먹었다.<end>

# %%
import os,re
import numpy as np
import pandas as pd
import tensorflow as tf

file_path ="./data/shakespeare.txt"
with open(file_path,'r') as f:
    raw_corpus = f.read().splitlines()
    
print(raw_corpus[:9])
# Out:
# ['First Citizen:', 'Before we proceed any further, hear me speak.', '', 'All:', 'Speak, speak.', '', 'First Citizen:', 'You are all resolved rather to die than to famish?', '']

# %%
for idx,sentence in enumerate(raw_corpus):
    if len(sentence)==0: continue
    if sentence[-1]==':': continue
    if idx>9: break
    print(sentence)
# Out:
# Before we proceed any further, hear me speak.
# Speak, speak.
# You are all resolved rather to die than to famish?

# %% [markdown]
# #  텐서플로우 전처리 과정

# %% [markdown]
# ## 1. 정규표현식을 이용한 corpus 생성
# ## 2. 코퍼스를 텐서로 변환
# ## 3. corpus 텐서를 tf.data.Dataset객체로 변환

# %% [markdown]
# # 1. 정규표현식을 이용한 corpus 생성
# #### 불필요한 공백, 특수문자를 제거하는 과정

# %%
def preprocess_sentence(sentence):
    sentence = sentence.lower().strip() # 1
    sentence = re.sub(r"([?.!,¿])", r" \1 ", sentence) # 2
    sentence = re.sub(r'[" "]+', " ", sentence) # 3
    sentence = re.sub(r"[^a-zA-Z?.!,¿]+", " ", sentence) # 4
    sentence = sentence.strip() # 5
    sentence = '<start> ' + sentence + ' <end>' # 6
    return sentence

print(preprocess_sentence("This @_is ;;;sample        sentence."))
# Out:
# <start> this is sample sentence . <end>

# %% [markdown]
# #### 공백이나 특수문자를 제거한 코퍼스를 10개만 확인해보자.

# %%
corpus = []

for sentence in raw_corpus:
    if len(sentence)==0: continue
    if sentence[-1] ==":" : continue
    
    preprocessd_sentence = preprocess_sentence(sentence)
    corpus.append(preprocessd_sentence)
    
corpus[:10]
# Out:
# ['<start> before we proceed any further , hear me speak . <end>',
#  '<start> speak , speak . <end>',
#  '<start> you are all resolved rather to die than to famish ? <end>',
#  '<start> resolved . resolved . <end>',
#  '<start> first , you know caius marcius is chief enemy to the people . <end>',
#  '<start> we know t , we know t . <end>',
#  '<start> let us kill him , and we ll have corn at our own price . <end>',
#  '<start> is t a verdict ? <end>',
#  '<start> no more talking on t let it be done away , away ! <end>',
#  '<start> one word , good citizens . <end>']

# %% [markdown]
# # 2. 코퍼스를 텐서로 변환
# ##### 벡터화 == 토큰화 ? 1. 문장을 토큰화 2. 토큰들을 단어사전으로 만든다. 3. 데이터를 숫자로 만들어준다. (텐서로 만들어준다.)

# %%
def tokenize(corpus):
    tokenizer = tf.keras.preprocessing.text.Tokenizer(
        num_words = 7000,
        filters = ' ',
        oov_token = "<unk>"
    )
    tokenizer.fit_on_texts(corpus) #문자 데이터를 입력받아 리스트 형태로 리턴 
    tensor = tokenizer.texts_to_sequences(corpus) #텍스트 안의 단어들을 숫자의 시퀀스로 변환
    
    #입력데이터의 시퀀스 길이를 일정하게 맞춰준다.
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor,padding='post')
    print(tensor,tokenizer)
    return tensor,tokenizer

# %%
tensor,tokenizer = tokenize(corpus)
# Out:
# [[   2  143   40 ...    0    0    0]
#  [   2  110    4 ...    0    0    0]
#  [   2   11   50 ...    0    0    0]
#  ...
#  [   2  149 4553 ...    0    0    0]
#  [   2   34   71 ...    0    0    0]
#  [   2  945   34 ...    0    0    0]] <keras_preprocessing.text.Tokenizer object at 0x7fe5d2b50990>

# %%
print(tensor[:1,:10])
# Out:
# [[  2 143  40 933 140 591   4 124  24 110]]

# %%
for idx in tokenizer.index_word:
    print(idx, ":",tokenizer.index_word[idx])
# Out:
# 1 : <unk>
# 2 : <start>
# 3 : <end>
# 4 : ,
# 5 : .
# 6 : the
# 7 : and
# 8 : i
# 9 : to
# 10 : of
# 11 : you
# 12 : my
# 13 : a
# 14 : that
# 15 : ?
# 16 : in
# 17 : !
# 18 : is
# 19 : not
# 20 : for
# 21 : s
# 22 : with
# 23 : it
# 24 : me
# 25 : your
# 26 : be
# 27 : he
# 28 : his
# 29 : but
# 30 : this
# 31 : have
# 32 : as
# 33 : d
# 34 : thou
# 35 : what
# 36 : him
# 37 : so
# 38 : will
# 39 : thy
# 40 : we
# 41 : by
# 42 : no
# 43 : all
# 44 : shall
# 45 : if
# 46 : her
# 47 : do
# 48 : our
# 49 : o
# 50 : are
# 51 : thee
# 52 : on
# 53 : now
# 54 : good
# 55 : lord
# 56 : come
# 57 : from
# 58 : which
# 59 : or
# 60 : sir
# 61 : more
# 62 : then
# 63 : ll
# 64 : at
# 65 : they
# 66 : here
# 67 : would
# 68 : was
# 69 : how
# 70 : she
# 71 : let
# 72 : well
# 73 : king
# 74 : than
# 75 : them
# 76 : say
# 77 : their
# 78 : am
# 79 : hath
# 80 : when
# 81 : there
# 82 : love
# 83 : one
# 84 : were
# 85 : go
# 86 : may
# 87 : upon
# 88 : us
# 89 : make
# 90 : like
# 91 : man
# 92 : know
# 93 : yet
# 94 : an
# 95 : should
# 96 : must
# 97 : why
# 98 : where
# 99 : had
# 100 : did
# 101 : father
# 102 : death
# 103 : tis
# 104 : see
# 105 : who
# 106 : some
# 107 : too
# 108 : give
# 109 : these
# 110 : speak
# 111 : such
# 112 : take
# 113 : can
# 114 : t
# 115 : mine
# 116 : out
# 117 : up
# 118 : god
# 119 : time
# 120 : tell
# 121 : most
# 122 : think
# 123 : son
# 124 : hear
# 125 : heart
# 126 : life
# 127 : made
# 128 : brother
# 129 : nor
# 130 : day
# 131 : never
# 132 : st
# 133 : much
# 134 : art
# 135 : look
# 136 : doth
# 137 : men
# 138 : true
# 139 : ay
# 140 : any
# 141 : cannot
# 142 : being
# 143 : before
# 144 : blood
# 145 : away
# 146 : name
# 147 : thus
# 148 : duke
# 149 : noble
# 150 : call
# 151 : honour
# 152 : again
# 153 : night
# 154 : fair
# 155 : been
# 156 : both
# 157 : hand
# 158 : pray
# 159 : very
# 160 : own
# 161 : done
# 162 : leave
# 163 : great
# 164 : sweet
# 165 : myself
# 166 : therefore
# 167 : though
# 168 : er
# 169 : against
# 170 : fear
# 171 : poor
# 172 : world
# 173 : queen
# 174 : edward
# 175 : hast
# 176 : heaven
# 177 : old
# 178 : nay
# 179 : down
# 180 : wife
# 181 : till
# 182 : way
# 183 : other
# 184 : stay
# 185 : mother
# 186 : live
# 187 : eyes
# 188 : comes
# 189 : ever
# 190 : grace
# 191 : bear
# 192 : even
# 193 : whose
# 194 : stand
# 195 : many
# 196 : dead
# 197 : master
# 198 : nothing
# 199 : first
# 200 : house
# 201 : die
# 202 : head
# 203 : henry
# 204 : friends
# 205 : those
# 206 : two
# 207 : romeo
# 208 : could
# 209 : warwick
# 210 : peace
# 211 : since
# 212 : better
# 213 : daughter
# 214 : soul
# 215 : word
# 216 : unto
# 217 : off
# 218 : news
# 219 : little
# 220 : gone
# 221 : lady
# 222 : still
# 223 : once
# 224 : thing
# 225 : long
# 226 : face
# 227 : whom
# 228 : hence
# 229 : else
# 230 : put
# 231 : set
# 232 : thine
# 233 : crown
# 234 : none
# 235 : richard
# 236 : prince
# 237 : ere
# 238 : himself
# 239 : might
# 240 : tongue
# 241 : rest
# 242 : young
# 243 : show
# 244 : words
# 245 : part
# 246 : dear
# 247 : lords
# 248 : gentle
# 249 : york
# 250 : best
# 251 : people
# 252 : back
# 253 : find
# 254 : power
# 255 : bring
# 256 : right
# 257 : farewell
# 258 : madam
# 259 : hope
# 260 : keep
# 261 : pardon
# 262 : earth
# 263 : came
# 264 : forth
# 265 : every
# 266 : home
# 267 : rome
# 268 : said
# 269 : place
# 270 : hands
# 271 : dost
# 272 : cause
# 273 : hold
# 274 : please
# 275 : into
# 276 : indeed
# 277 : heard
# 278 : husband
# 279 : welcome
# 280 : help
# 281 : after
# 282 : has
# 283 : about
# 284 : boy
# 285 : cousin
# 286 : thought
# 287 : bid
# 288 : full
# 289 : tears
# 290 : answer
# 291 : mind
# 292 : wilt
# 293 : marry
# 294 : state
# 295 : friend
# 296 : mean
# 297 : shame
# 298 : marcius
# 299 : morrow
# 300 : fellow
# 301 : gentleman
# 302 : thousand
# 303 : only
# 304 : eye
# 305 : kill
# 306 : makes
# 307 : within
# 308 : another
# 309 : three
# 310 : child
# 311 : hither
# 312 : last
# 313 : gracious
# 314 : mistress
# 315 : clarence
# 316 : rather
# 317 : while
# 318 : body
# 319 : far
# 320 : prove
# 321 : war
# 322 : lay
# 323 : use
# 324 : meet
# 325 : bed
# 326 : hour
# 327 : lie
# 328 : fortune
# 329 : royal
# 330 : sorrow
# 331 : angelo
# 332 : shalt
# 333 : lies
# 334 : woman
# 335 : enough
# 336 : beseech
# 337 : joy
# 338 : less
# 339 : fall
# 340 : comfort
# 341 : nature
# 342 : swear
# 343 : end
# 344 : business
# 345 : grave
# 346 : sun
# 347 : follow
# 348 : saw
# 349 : play
# 350 : turn
# 351 : years
# 352 : talk
# 353 : sea
# 354 : happy
# 355 : grief
# 356 : law
# 357 : matter
# 358 : truth
# 359 : without
# 360 : holy
# 361 : gods
# 362 : things
# 363 : faith
# 364 : thank
# 365 : pity
# 366 : wrong
# 367 : kind
# 368 : hate
# 369 : wish
# 370 : light
# 371 : false
# 372 : ah
# 373 : friar
# 374 : get
# 375 : save
# 376 : lives
# 377 : new
# 378 : arms
# 379 : means
# 380 : present
# 381 : bloody
# 382 : believe
# 383 : kate
# 384 : ne
# 385 : send
# 386 : high
# 387 : yourself
# 388 : does
# 389 : horse
# 390 : sleep
# 391 : villain
# 392 : foul
# 393 : country
# 394 : city
# 395 : worthy
# 396 : fight
# 397 : sovereign
# 398 : land
# 399 : seem
# 400 : mercy
# 401 : proud
# 402 : under
# 403 : sit
# 404 : yours
# 405 : looks
# 406 : left
# 407 : through
# 408 : fire
# 409 : sword
# 410 : told
# 411 : sound
# 412 : england
# 413 : uncle
# 414 : together
# 415 : doubt
# 416 : seen
# 417 : thyself
# 418 : maid
# 419 : sister
# 420 : tybalt
# 421 : either
# 422 : mark
# 423 : break
# 424 : breath
# 425 : traitor
# 426 : kiss
# 427 : need
# 428 : arm
# 429 : heavy
# 430 : nurse
# 431 : children
# 432 : majesty
# 433 : woe
# 434 : ill
# 435 : alas
# 436 : purpose
# 437 : remember
# 438 : justice
# 439 : days
# 440 : ready
# 441 : born
# 442 : lost
# 443 : signior
# 444 : ears
# 445 : return
# 446 : spirit
# 447 : times
# 448 : twenty
# 449 : liege
# 450 : report
# 451 : strike
# 452 : because
# 453 : says
# 454 : each
# 455 : strange
# 456 : twas
# 457 : late
# 458 : foot
# 459 : pass
# 460 : banish
# 461 : canst
# 462 : care
# 463 : common
# 464 : general
# 465 : cry
# 466 : fool
# 467 : warrant
# 468 : deep
# 469 : having
# 470 : reason
# 471 : free
# 472 : weep
# 473 : age
# 474 : lest
# 475 : didst
# 476 : beauty
# 477 : bolingbroke
# 478 : content
# 479 : ye
# 480 : sent
# 481 : tender
# 482 : over
# 483 : thoughts
# 484 : hours
# 485 : yea
# 486 : service
# 487 : married
# 488 : clifford
# 489 : juliet
# 490 : ha
# 491 : sin
# 492 : half
# 493 : person
# 494 : alone
# 495 : charge
# 496 : stands
# 497 : knows
# 498 : desire
# 499 : ground
# 500 : near
# 501 : cold
# 502 : women
# 503 : oath
# 504 : thanks
# 505 : fault
# 506 : brought
# 507 : open
# 508 : slain
# 509 : air
# 510 : twere
# 511 : soon
# 512 : sight
# 513 : enemy
# 514 : yield
# 515 : tale
# 516 : court
# 517 : found
# 518 : haste
# 519 : gentlemen
# 520 : straight
# 521 : loss
# 522 : widow
# 523 : hastings
# 524 : saint
# 525 : side
# 526 : honest
# 527 : trust
# 528 : lose
# 529 : heavens
# 530 : prithee
# 531 : itself
# 532 : touch
# 533 : deed
# 534 : sure
# 535 : ear
# 536 : unless
# 537 : gloucester
# 538 : buckingham
# 539 : dream
# 540 : france
# 541 : montague
# 542 : claudio
# 543 : ten
# 544 : known
# 545 : fie
# 546 : command
# 547 : fearful
# 548 : cut
# 549 : mad
# 550 : prison
# 551 : marriage
# 552 : camillo
# 553 : virtue
# 554 : point
# 555 : pale
# 556 : souls
# 557 : hell
# 558 : serve
# 559 : draw
# 560 : fly
# 561 : learn
# 562 : something
# 563 : loving
# 564 : read
# 565 : knew
# 566 : duty
# 567 : norfolk
# 568 : revenge
# 569 : work
# 570 : change
# 571 : bound
# 572 : pluck
# 573 : beat
# 574 : dare
# 575 : same
# 576 : ask
# 577 : wear
# 578 : voices
# 579 : withal
# 580 : next
# 581 : lancaster
# 582 : youth
# 583 : seek
# 584 : hark
# 585 : hearts
# 586 : sake
# 587 : past
# 588 : counsel
# 589 : heir
# 590 : sirrah
# 591 : further
# 592 : become
# 593 : enemies
# 594 : deliver
# 595 : run
# 596 : field
# 597 : strength
# 598 : gates
# 599 : ho
# 600 : wind
# 601 : brave
# 602 : behold
# 603 : given
# 604 : lucentio
# 605 : course
# 606 : confess
# 607 : company
# 608 : yes
# 609 : worse
# 610 : themselves
# 611 : between
# 612 : fast
# 613 : took
# 614 : neither
# 615 : merry
# 616 : pleasure
# 617 : coming
# 618 : lips
# 619 : bosom
# 620 : highness
# 621 : loved
# 622 : curse
# 623 : rich
# 624 : patience
# 625 : bold
# 626 : aufidius
# 627 : goes
# 628 : met
# 629 : coriolanus
# 630 : devil
# 631 : forget
# 632 : title
# 633 : sad
# 634 : soldiers
# 635 : tower
# 636 : murder
# 637 : petruchio
# 638 : soft
# 639 : already
# 640 : along
# 641 : kings
# 642 : whilst
# 643 : bad
# 644 : office
# 645 : enter
# 646 : watch
# 647 : just
# 648 : tranio
# 649 : bianca
# 650 : fit
# 651 : hang
# 652 : wonder
# 653 : sons
# 654 : methinks
# 655 : fetch
# 656 : hadst
# 657 : gave
# 658 : water
# 659 : speed
# 660 : hereford
# 661 : subject
# 662 : strong
# 663 : appear
# 664 : wars
# 665 : thence
# 666 : sworn
# 667 : wherein
# 668 : issue
# 669 : jest
# 670 : spoke
# 671 : foe
# 672 : wounds
# 673 : loves
# 674 : morning
# 675 : grant
# 676 : black
# 677 : wit
# 678 : tribunes
# 679 : buy
# 680 : dangerous
# 681 : woo
# 682 : wert
# 683 : en
# 684 : often
# 685 : worth
# 686 : consul
# 687 : ancient
# 688 : voice
# 689 : entreat
# 690 : presence
# 691 : quarrel
# 692 : throne
# 693 : margaret
# 694 : order
# 695 : music
# 696 : faults
# 697 : thither
# 698 : battle
# 699 : throw
# 700 : attend
# 701 : prayers
# 702 : brief
# 703 : march
# 704 : slave
# 705 : deny
# 706 : hard
# 707 : consent
# 708 : begin
# 709 : princely
# 710 : request
# 711 : suit
# 712 : seems
# 713 : george
# 714 : mighty
# 715 : richmond
# 716 : london
# 717 : deeds
# 718 : alack
# 719 : feel
# 720 : win
# 721 : almost
# 722 : five
# 723 : mock
# 724 : whether
# 725 : want
# 726 : harm
# 727 : e
# 728 : poison
# 729 : hot
# 730 : measure
# 731 : wise
# 732 : knock
# 733 : vow
# 734 : paris
# 735 : vi
# 736 : baptista
# 737 : em
# 738 : suffer
# 739 : ld
# 740 : promise
# 741 : valiant
# 742 : whence
# 743 : got
# 744 : above
# 745 : gold
# 746 : self
# 747 : mortal
# 748 : flesh
# 749 : breast
# 750 : anon
# 751 : speech
# 752 : presently
# 753 : living
# 754 : case
# 755 : pompey
# 756 : pretty
# 757 : awhile
# 758 : re
# 759 : moon
# 760 : perform
# 761 : hearing
# 762 : ladies
# 763 : town
# 764 : base
# 765 : breathe
# 766 : wash
# 767 : least
# 768 : subjects
# 769 : wherefore
# 770 : deserved
# 771 : heads
# 772 : towards
# 773 : rage
# 774 : worship
# 775 : move
# 776 : offer
# 777 : close
# 778 : slaughter
# 779 : bohemia
# 780 : soldier
# 781 : worst
# 782 : offence
# 783 : besides
# 784 : tear
# 785 : shows
# 786 : doing
# 787 : beg
# 788 : whither
# 789 : letters
# 790 : ourselves
# 791 : laid
# 792 : kingdom
# 793 : hortensio
# 794 : defend
# 795 : behind
# 796 : held
# 797 : dispatch
# 798 : four
# 799 : needs
# 800 : stir
# 801 : bless
# 802 : knee
# 803 : wast
# 804 : quickly
# 805 : feast
# 806 : wouldst
# 807 : toward
# 808 : blows
# 809 : virtuous
# 810 : amen
# 811 : goodly
# 812 : book
# 813 : lawful
# 814 : banishment
# 815 : weeping
# 816 : witness
# 817 : join
# 818 : bawd
# 819 : provost
# 820 : padua
# 821 : katharina
# 822 : citizens
# 823 : small
# 824 : note
# 825 : seat
# 826 : lead
# 827 : lack
# 828 : action
# 829 : letter
# 830 : chance
# 831 : fine
# 832 : fill
# 833 : sudden
# 834 : shed
# 835 : ta
# 836 : truly
# 837 : forgot
# 838 : angry
# 839 : chamber
# 840 : servant
# 841 : white
# 842 : slew
# 843 : conscience
# 844 : seal
# 845 : piece
# 846 : bears
# 847 : clouds
# 848 : plain
# 849 : patient
# 850 : cross
# 851 : rough
# 852 : longer
# 853 : year
# 854 : leisure
# 855 : golden
# 856 : northumberland
# 857 : guilty
# 858 : oxford
# 859 : gaunt
# 860 : grumio
# 861 : guess
# 862 : act
# 863 : aside
# 864 : greater
# 865 : won
# 866 : obey
# 867 : hundred
# 868 : noise
# 869 : shake
# 870 : certain
# 871 : short
# 872 : hide
# 873 : pay
# 874 : steel
# 875 : prisoner
# 876 : pride
# 877 : drink
# 878 : lived
# 879 : dry
# 880 : stood
# 881 : oft
# 882 : fled
# 883 : sense
# 884 : liberty
# 885 : mouth
# 886 : dishonour
# 887 : forbid
# 888 : banished
# 889 : forward
# 890 : money
# 891 : post
# 892 : lordship
# 893 : alive
# 894 : plantagenet
# 895 : green
# 896 : gremio
# 897 : dog
# 898 : masters
# 899 : yourselves
# 900 : remain
# 901 : labour
# 902 : speaks
# 903 : quoth
# 904 : rise
# 905 : broke
# 906 : moved
# 907 : honours
# 908 : safe
# 909 : visit
# 910 : neck
# 911 : shepherd
# 912 : grow
# 913 : honourable
# 914 : cast
# 915 : knowledge
# 916 : twixt
# 917 : match
# 918 : warm
# 919 : commend
# 920 : frown
# 921 : favour
# 922 : kneel
# 923 : vain
# 924 : until
# 925 : glory
# 926 : few
# 927 : shore
# 928 : pain
# 929 : catesby
# 930 : kinsman
# 931 : john
# 932 : isabel
# 933 : proceed
# 934 : knees
# 935 : walk
# 936 : flatter
# 937 : sick
# 938 : glad
# 939 : fought
# 940 : army
# 941 : womb
# 942 : danger
# 943 : died
# 944 : blow
# 945 : whiles
# 946 : struck
# 947 : gainst
# 948 : wretch
# 949 : weary
# 950 : encounter
# 951 : force
# 952 : stain
# 953 : seven
# 954 : victory
# 955 : cheeks
# 956 : form
# 957 : judge
# 958 : wisdom
# 959 : scorn
# 960 : twice
# 961 : stop
# 962 : choose
# 963 : bones
# 964 : try
# 965 : wild
# 966 : teach
# 967 : going
# 968 : liest
# 969 : blessed
# 970 : birth
# 971 : prepare
# 972 : summer
# 973 : weak
# 974 : fresh
# 975 : quiet
# 976 : wench
# 977 : brothers
# 978 : cheer
# 979 : spent
# 980 : woes
# 981 : promised
# 982 : proclaim
# 983 : earl
# 984 : bride
# 985 : slander
# 986 : eat
# 987 : smile
# 988 : stone
# 989 : walls
# 990 : valour
# 991 : grown
# 992 : sort
# 993 : carry
# 994 : doom
# 995 : malice
# 996 : deadly
# 997 : precious
# 998 : adieu
# 999 : six
# 1000 : humble
# 1001 : judgment
# 1002 : kept
# 1003 : officer
# 1004 : despair
# 1005 : fond
# 1006 : calls
# 1007 : kindness
# 1008 : herself
# 1009 : winter
# 1010 : grey
# 1011 : kindred
# 1012 : abroad
# 1013 : secret
# 1014 : creature
# 1015 : usurp
# 1016 : bitter
# 1017 : aumerle
# 1018 : lands
# 1019 : mercutio
# 1020 : lewis
# 1021 : caius
# 1022 : account
# 1023 : idle
# 1024 : rivers
# 1025 : vile
# 1026 : making
# 1027 : volsces
# 1028 : cominius
# 1029 : cruel
# 1030 : swords
# 1031 : excuse
# 1032 : door
# 1033 : quick
# 1034 : flower
# 1035 : silence
# 1036 : tent
# 1037 : cried
# 1038 : gives
# 1039 : health
# 1040 : tongues
# 1041 : manner
# 1042 : execution
# 1043 : trouble
# 1044 : drawn
# 1045 : repent
# 1046 : foes
# 1047 : awake
# 1048 : divine
# 1049 : treason
# 1050 : beggar
# 1051 : thinks
# 1052 : bids
# 1053 : stars
# 1054 : dance
# 1055 : charity
# 1056 : dreams
# 1057 : simple
# 1058 : wretched
# 1059 : humour
# 1060 : honesty
# 1061 : bright
# 1062 : drown
# 1063 : fain
# 1064 : swift
# 1065 : flowers
# 1066 : thomas
# 1067 : early
# 1068 : satisfied
# 1069 : went
# 1070 : harry
# 1071 : drunk
# 1072 : english
# 1073 : county
# 1074 : peter
# 1075 : church
# 1076 : paulina
# 1077 : vincentio
# 1078 : vice
# 1079 : always
# 1080 : evil
# 1081 : party
# 1082 : therein
# 1083 : hair
# 1084 : brow
# 1085 : fell
# 1086 : fare
# 1087 : view
# 1088 : lend
# 1089 : ours
# 1090 : silver
# 1091 : second
# 1092 : foolish
# 1093 : others
# 1094 : burn
# 1095 : plague
# 1096 : aid
# 1097 : nose
# 1098 : sometime
# 1099 : condition
# 1100 : guard
# 1101 : deserve
# 1102 : received
# 1103 : nine
# 1104 : dark
# 1105 : laugh
# 1106 : question
# 1107 : easy
# 1108 : blind
# 1109 : maids
# 1110 : vengeance
# 1111 : blest
# 1112 : taken
# 1113 : crave
# 1114 : spake
# 1115 : trial
# 1116 : although
# 1117 : sentence
# 1118 : safety
# 1119 : mayst
# 1120 : mistake
# 1121 : bite
# 1122 : writ
# 1123 : changed
# 1124 : glass
# 1125 : betwixt
# 1126 : lo
# 1127 : cursed
# 1128 : wicked
# 1129 : quite
# 1130 : wither
# 1131 : desperate
# 1132 : reign
# 1133 : tyrant
# 1134 : mowbray
# 1135 : sour
# 1136 : mantua
# 1137 : corn
# 1138 : menenius
# 1139 : senate
# 1140 : undone
# 1141 : affection
# 1142 : sigh
# 1143 : meat
# 1144 : sing
# 1145 : absence
# 1146 : becomes
# 1147 : troth
# 1148 : yonder
# 1149 : proof
# 1150 : red
# 1151 : drop
# 1152 : dull
# 1153 : trumpets
# 1154 : perceive
# 1155 : prayer
# 1156 : blame
# 1157 : triumph
# 1158 : sheep
# 1159 : jove
# 1160 : leaves
# 1161 : coward
# 1162 : weeds
# 1163 : ease
# 1164 : gown
# 1165 : private
# 1166 : practise
# 1167 : dust
# 1168 : anger
# 1169 : reasons
# 1170 : traitors
# 1171 : despite
# 1172 : seize
# 1173 : remedy
# 1174 : fiery
# 1175 : possess
# 1176 : bow
# 1177 : courage
# 1178 : wail
# 1179 : supper
# 1180 : fellows
# 1181 : twelve
# 1182 : sits
# 1183 : scarce
# 1184 : enjoy
# 1185 : corse
# 1186 : buried
# 1187 : belike
# 1188 : thereof
# 1189 : deposed
# 1190 : resign
# 1191 : steal
# 1192 : cheek
# 1193 : occasion
# 1194 : castle
# 1195 : clock
# 1196 : ship
# 1197 : deputy
# 1198 : rid
# 1199 : resolve
# 1200 : sacred
# 1201 : resolved
# 1202 : authority
# 1203 : capitol
# 1204 : devise
# 1205 : belly
# 1206 : former
# 1207 : receive
# 1208 : benefit
# 1209 : hail
# 1210 : whereof
# 1211 : passing
# 1212 : choice
# 1213 : borne
# 1214 : prepared
# 1215 : wall
# 1216 : pleased
# 1217 : seeing
# 1218 : tread
# 1219 : countenance
# 1220 : teeth
# 1221 : corioli
# 1222 : wives
# 1223 : followers
# 1224 : envy
# 1225 : shouldst
# 1226 : faced
# 1227 : blush
# 1228 : rotten
# 1229 : lamb
# 1230 : motion
# 1231 : ones
# 1232 : stuff
# 1233 : among
# 1234 : owe
# 1235 : garments
# 1236 : repair
# 1237 : used
# 1238 : ignorant
# 1239 : taste
# 1240 : double
# 1241 : cure
# 1242 : demand
# 1243 : stones
# 1244 : throat
# 1245 : knave
# 1246 : spirits
# 1247 : cunning
# 1248 : quit
# 1249 : darest
# 1250 : possible
# 1251 : understand
# 1252 : names
# 1253 : sometimes
# 1254 : deceived
# 1255 : captain
# 1256 : hanging
# 1257 : affairs
# 1258 : tidings
# 1259 : bark
# 1260 : begins
# 1261 : fatal
# 1262 : effect
# 1263 : rutland
# 1264 : woful
# 1265 : envious
# 1266 : meaning
# 1267 : pains
# 1268 : hie
# 1269 : christian
# 1270 : broken
# 1271 : princes
# 1272 : neighbour
# 1273 : depart
# 1274 : rude
# 1275 : storm
# 1276 : fares
# 1277 : stanley
# 1278 : garden
# 1279 : farther
# 1280 : hit
# 1281 : spring
# 1282 : crowns
# 1283 : girl
# 1284 : seeming
# 1285 : cell
# 1286 : clear
# 1287 : somerset
# 1288 : hermione
# 1289 : apollo
# 1290 : pisa
# 1291 : roman
# 1292 : whole
# 1293 : parts
# 1294 : brain
# 1295 : cares
# 1296 : deserves
# 1297 : several
# 1298 : lip
# 1299 : spare
# 1300 : success
# 1301 : aught
# 1302 : brows
# 1303 : finger
# 1304 : shut
# 1305 : beyond
# 1306 : big
# 1307 : thunder
# 1308 : prize
# 1309 : violent
# 1310 : outward
# 1311 : seest
# 1312 : sign
# 1313 : write
# 1314 : wine
# 1315 : follows
# 1316 : pair
# 1317 : wanton
# 1318 : nobles
# 1319 : cries
# 1320 : standing
# 1321 : tune
# 1322 : claim
# 1323 : denied
# 1324 : pawn
# 1325 : courtesy
# 1326 : spoken
# 1327 : respect
# 1328 : rock
# 1329 : withdraw
# 1330 : beloved
# 1331 : perish
# 1332 : bend
# 1333 : chide
# 1334 : faint
# 1335 : wrongs
# 1336 : thrive
# 1337 : daughters
# 1338 : fruit
# 1339 : priest
# 1340 : sighs
# 1341 : forsworn
# 1342 : wings
# 1343 : paper
# 1344 : dreadful
# 1345 : untimely
# 1346 : miserable
# 1347 : damned
# 1348 : happiness
# 1349 : plead
# 1350 : due
# 1351 : low
# 1352 : tedious
# 1353 : keeps
# 1354 : tut
# 1355 : hollow
# 1356 : oracle
# 1357 : mayor
# 1358 : sorry
# 1359 : add
# 1360 : pleasant
# 1361 : biondello
# 1362 : services
# 1363 : intend
# 1364 : bearing
# 1365 : minister
# 1366 : kingly
# 1367 : natural
# 1368 : vantage
# 1369 : opinion
# 1370 : prevail
# 1371 : bred
# 1372 : shadow
# 1373 : press
# 1374 : drum
# 1375 : school
# 1376 : hereafter
# 1377 : list
# 1378 : hurt
# 1379 : faces
# 1380 : flight
# 1381 : pack
# 1382 : praise
# 1383 : inform
# 1384 : disposition
# 1385 : number
# 1386 : beheld
# 1387 : horses
# 1388 : wrath
# 1389 : twill
# 1390 : naked
# 1391 : fools
# 1392 : spend
# 1393 : legs
# 1394 : table
# 1395 : wont
# 1396 : large
# 1397 : renowned
# 1398 : theirs
# 1399 : leads
# 1400 : terror
# 1401 : sport
# 1402 : gate
# 1403 : painted
# 1404 : curses
# 1405 : advantage
# 1406 : rule
# 1407 : obedience
# 1408 : ways
# 1409 : waters
# 1410 : colour
# 1411 : dies
# 1412 : peril
# 1413 : asleep
# 1414 : accuse
# 1415 : wot
# 1416 : thrust
# 1417 : lament
# 1418 : looking
# 1419 : durst
# 1420 : led
# 1421 : forgive
# 1422 : dinner
# 1423 : kin
# 1424 : condemn
# 1425 : tide
# 1426 : n
# 1427 : humbly
# 1428 : curst
# 1429 : empty
# 1430 : piteous
# 1431 : story
# 1432 : dukedom
# 1433 : dread
# 1434 : hopes
# 1435 : bona
# 1436 : burthen
# 1437 : contrary
# 1438 : assurance
# 1439 : dares
# 1440 : instrument
# 1441 : palace
# 1442 : apparel
# 1443 : wedding
# 1444 : capulet
# 1445 : verona
# 1446 : its
# 1447 : thursday
# 1448 : continue
# 1449 : polixenes
# 1450 : barnardine
# 1451 : gain
# 1452 : consider
# 1453 : unknown
# 1454 : wants
# 1455 : takes
# 1456 : fathers
# 1457 : houses
# 1458 : folly
# 1459 : senators
# 1460 : fore
# 1461 : finds
# 1462 : desires
# 1463 : puts
# 1464 : commanded
# 1465 : east
# 1466 : express
# 1467 : excellent
# 1468 : drums
# 1469 : mend
# 1470 : tremble
# 1471 : powers
# 1472 : delay
# 1473 : able
# 1474 : smiles
# 1475 : camest
# 1476 : grows
# 1477 : proper
# 1478 : custom
# 1479 : thief
# 1480 : discover
# 1481 : reverend
# 1482 : den
# 1483 : wounded
# 1484 : brings
# 1485 : third
# 1486 : root
# 1487 : hatred
# 1488 : giving
# 1489 : remains
# 1490 : scene
# 1491 : dying
# 1492 : perpetual
# 1493 : intent
# 1494 : monstrous
# 1495 : called
# 1496 : thrice
# 1497 : contempt
# 1498 : worn
# 1499 : hardly
# 1500 : fortunes
# 1501 : calm
# 1502 : plot
# 1503 : unnatural
# 1504 : respected
# 1505 : language
# 1506 : bare
# 1507 : stoop
# 1508 : ends
# 1509 : begun
# 1510 : allow
# 1511 : beast
# 1512 : month
# 1513 : loud
# 1514 : groan
# 1515 : turns
# 1516 : enmity
# 1517 : guest
# 1518 : rt
# 1519 : drops
# 1520 : methought
# 1521 : passage
# 1522 : flies
# 1523 : fairly
# 1524 : fail
# 1525 : chair
# 1526 : shortly
# 1527 : glorious
# 1528 : access
# 1529 : accept
# 1530 : winds
# 1531 : perhaps
# 1532 : advise
# 1533 : knife
# 1534 : degree
# 1535 : resolution
# 1536 : entertain
# 1537 : convey
# 1538 : protest
# 1539 : prey
# 1540 : supposed
# 1541 : accursed
# 1542 : wept
# 1543 : sharp
# 1544 : ring
# 1545 : joys
# 1546 : french
# 1547 : gross
# 1548 : dorset
# 1549 : hateful
# 1550 : sins
# 1551 : purse
# 1552 : room
# 1553 : perfect
# 1554 : committed
# 1555 : suspicion
# 1556 : remembrance
# 1557 : unhappy
# 1558 : debt
# 1559 : government
# 1560 : isle
# 1561 : realm
# 1562 : terms
# 1563 : hid
# 1564 : scope
# 1565 : seas
# 1566 : boot
# 1567 : blunt
# 1568 : princess
# 1569 : hearted
# 1570 : colours
# 1571 : needful
# 1572 : gage
# 1573 : sceptre
# 1574 : lusty
# 1575 : credit
# 1576 : goodness
# 1577 : passion
# 1578 : gentlewoman
# 1579 : naples
# 1580 : sicilia
# 1581 : froth
# 1582 : misery
# 1583 : partly
# 1584 : daily
# 1585 : wondrous
# 1586 : serves
# 1587 : instruments
# 1588 : instruct
# 1589 : sink
# 1590 : veins
# 1591 : rascal
# 1592 : below
# 1593 : granted
# 1594 : lion
# 1595 : greatest
# 1596 : fame
# 1597 : fashion
# 1598 : profess
# 1599 : alike
# 1600 : mile
# 1601 : amongst
# 1602 : romans
# 1603 : charged
# 1604 : forced
# 1605 : cease
# 1606 : conduct
# 1607 : top
# 1608 : beard
# 1609 : sanctuary
# 1610 : tells
# 1611 : single
# 1612 : cup
# 1613 : meeting
# 1614 : prosperous
# 1615 : shoulder
# 1616 : trees
# 1617 : sway
# 1618 : sore
# 1619 : plainly
# 1620 : sail
# 1621 : north
# 1622 : roar
# 1623 : counterfeit
# 1624 : advised
# 1625 : bodies
# 1626 : thinking
# 1627 : wrought
# 1628 : yond
# 1629 : punish
# 1630 : assured
# 1631 : quench
# 1632 : odds
# 1633 : nought
# 1634 : dam
# 1635 : undertake
# 1636 : armour
# 1637 : frame
# 1638 : plant
# 1639 : behalf
# 1640 : joyful
# 1641 : trick
# 1642 : avoid
# 1643 : comest
# 1644 : spite
# 1645 : muster
# 1646 : imagine
# 1647 : iron
# 1648 : bastard
# 1649 : tame
# 1650 : destroy
# 1651 : messenger
# 1652 : raised
# 1653 : embrace
# 1654 : urge
# 1655 : apparent
# 1656 : tomb
# 1657 : groans
# 1658 : jack
# 1659 : jealous
# 1660 : heed
# 1661 : pieces
# 1662 : treacherous
# 1663 : heirs
# 1664 : imprisonment
# 1665 : perforce
# 1666 : grievous
# 1667 : fairer
# 1668 : wreck
# 1669 : revenged
# 1670 : afford
# 1671 : sickness
# 1672 : contented
# 1673 : grandam
# 1674 : innocent
# 1675 : lovely
# 1676 : sky
# 1677 : meant
# 1678 : offended
# 1679 : sends
# 1680 : bethink
# 1681 : forthwith
# 1682 : wound
# 1683 : slow
# 1684 : dagger
# 1685 : gift
# 1686 : boar
# 1687 : contract
# 1688 : manners
# 1689 : reverence
# 1690 : pure
# 1691 : wed
# 1692 : dew
# 1693 : advice
# 1694 : shape
# 1695 : deal
# 1696 : lark
# 1697 : slept
# 1698 : arrived
# 1699 : special
# 1700 : dish
# 1701 : trade
# 1702 : weather
# 1703 : raise
# 1704 : parliament
# 1705 : happily
# 1706 : rogue
# 1707 : vault
# 1708 : tarry
# 1709 : island
# 1710 : shrew
# 1711 : patricians
# 1712 : wholesome
# 1713 : store
# 1714 : repeal
# 1715 : complain
# 1716 : affections
# 1717 : increase
# 1718 : feed
# 1719 : slaves
# 1720 : dogs
# 1721 : mouths
# 1722 : hunt
# 1723 : constant
# 1724 : titus
# 1725 : lean
# 1726 : equal
# 1727 : brook
# 1728 : aim
# 1729 : remove
# 1730 : assist
# 1731 : sell
# 1732 : beholding
# 1733 : nobly
# 1734 : task
# 1735 : spit
# 1736 : caught
# 1737 : afternoon
# 1738 : fears
# 1739 : lesser
# 1740 : south
# 1741 : market
# 1742 : stamp
# 1743 : exile
# 1744 : vows
# 1745 : endure
# 1746 : reward
# 1747 : refuse
# 1748 : butcher
# 1749 : fury
# 1750 : according
# 1751 : beasts
# 1752 : ass
# 1753 : dismiss
# 1754 : estate
# 1755 : soundly
# 1756 : commons
# 1757 : devotion
# 1758 : silent
# 1759 : length
# 1760 : willingly
# 1761 : weigh
# 1762 : pierce
# 1763 : virtues
# 1764 : desert
# 1765 : odd
# 1766 : enforce
# 1767 : began
# 1768 : yielded
# 1769 : yoke
# 1770 : regard
# 1771 : current
# 1772 : ruin
# 1773 : holp
# 1774 : hap
# 1775 : streets
# 1776 : warlike
# 1777 : graves
# 1778 : season
# 1779 : served
# 1780 : ripe
# 1781 : entertainment
# 1782 : slay
# 1783 : commission
# 1784 : weakness
# 1785 : hanged
# 1786 : ballad
# 1787 : waking
# 1788 : freely
# 1789 : bore
# 1790 : rights
# 1791 : urged
# 1792 : haply
# 1793 : tyranny
# 1794 : persuade
# 1795 : attempt
# 1796 : wide
# 1797 : greet
# 1798 : grieve
# 1799 : salt
# 1800 : dove
# 1801 : loyal
# 1802 : mourn
# 1803 : smooth
# 1804 : murderer
# 1805 : appointed
# 1806 : conference
# 1807 : forbear
# 1808 : employ
# 1809 : stabb
# 1810 : venom
# 1811 : mild
# 1812 : stroke
# 1813 : maintain
# 1814 : protector
# 1815 : derby
# 1816 : suppose
# 1817 : babe
# 1818 : breathed
# 1819 : taught
# 1820 : sleeping
# 1821 : elbow
# 1822 : powerful
# 1823 : feeling
# 1824 : expect
# 1825 : falsehood
# 1826 : peers
# 1827 : forfeit
# 1828 : bade
# 1829 : image
# 1830 : obedient
# 1831 : lent
# 1832 : firm
# 1833 : growing
# 1834 : pomfret
# 1835 : caesar
# 1836 : famous
# 1837 : betimes
# 1838 : conceit
# 1839 : sees
# 1840 : tied
# 1841 : round
# 1842 : anointed
# 1843 : tyrrel
# 1844 : exeter
# 1845 : ireland
# 1846 : morn
# 1847 : offend
# 1848 : bishop
# 1849 : cock
# 1850 : fairest
# 1851 : ago
# 1852 : twain
# 1853 : gently
# 1854 : sue
# 1855 : approach
# 1856 : absent
# 1857 : wooing
# 1858 : waste
# 1859 : amazed
# 1860 : boots
# 1861 : regal
# 1862 : oaths
# 1863 : abide
# 1864 : rosaline
# 1865 : lucio
# 1866 : exchange
# 1867 : assure
# 1868 : aboard
# 1869 : impossible
# 1870 : satisfy
# 1871 : dowry
# 1872 : froward
# 1873 : vienna
# 1874 : hic
# 1875 : milan
# 1876 : barren
# 1877 : countrymen
# 1878 : suitors
# 1879 : lift
# 1880 : accused
# 1881 : disgrace
# 1882 : appetite
# 1883 : food
# 1884 : greatness
# 1885 : garland
# 1886 : places
# 1887 : tullus
# 1888 : graced
# 1889 : lets
# 1890 : west
# 1891 : hated
# 1892 : gaze
# 1893 : oak
# 1894 : eleven
# 1895 : crack
# 1896 : earnest
# 1897 : wager
# 1898 : pound
# 1899 : instruction
# 1900 : advance
# 1901 : edge
# 1902 : fires
# 1903 : jewel
# 1904 : strokes
# 1905 : bury
# 1906 : exercise
# 1907 : sirs
# 1908 : chase
# 1909 : holding
# 1910 : slip
# 1911 : willing
# 1912 : whip
# 1913 : memory
# 1914 : subtle
# 1915 : privilege
# 1916 : spur
# 1917 : journey
# 1918 : wolf
# 1919 : infant
# 1920 : hasty
# 1921 : utter
# 1922 : knaves
# 1923 : bleeding
# 1924 : saying
# 1925 : newly
# 1926 : fancy
# 1927 : sights
# 1928 : human
# 1929 : miss
# 1930 : rare
# 1931 : vessel
# 1932 : wits
# 1933 : direct
# 1934 : points
# 1935 : block
# 1936 : fourth
# 1937 : kindly
# 1938 : hat
# 1939 : heartily
# 1940 : marks
# 1941 : knowing
# 1942 : friendly
# 1943 : gall
# 1944 : ruled
# 1945 : abused
# 1946 : catch
# 1947 : absolute
# 1948 : ignorance
# 1949 : thread
# 1950 : sets
# 1951 : infection
# 1952 : craves
# 1953 : policy
# 1954 : suck
# 1955 : determine
# 1956 : deaths
# 1957 : extremity
# 1958 : younger
# 1959 : dearest
# 1960 : vex
# 1961 : adversaries
# 1962 : boys
# 1963 : necessity
# 1964 : particular
# 1965 : ado
# 1966 : wipe
# 1967 : trembling
# 1968 : rash
# 1969 : fish
# 1970 : sovereignty
# 1971 : writing
# 1972 : blown
# 1973 : temper
# 1974 : italy
# 1975 : foreign
# 1976 : wait
# 1977 : reap
# 1978 : holds
# 1979 : dearly
# 1980 : parted
# 1981 : betray
# 1982 : eagle
# 1983 : steeds
# 1984 : fright
# 1985 : proportion
# 1986 : delight
# 1987 : melancholy
# 1988 : paul
# 1989 : youngest
# 1990 : ghost
# 1991 : selfsame
# 1992 : swallow
# 1993 : govern
# 1994 : vouchsafe
# 1995 : toad
# 1996 : pause
# 1997 : sorrows
# 1998 : arise
# 1999 : penitent
# 2000 : sly
# 2001 : suitor
# 2002 : pitiful
# 2003 : strew
# 2004 : strive
# 2005 : tempest
# 2006 : execute
# 2007 : keeper
# 2008 : wakes
# 2009 : gallant
# 2010 : redeem
# 2011 : purchase
# 2012 : dukes
# 2013 : feet
# 2014 : torment
# 2015 : aunt
# 2016 : weeps
# 2017 : babes
# 2018 : star
# 2019 : uncles
# 2020 : prevent
# 2021 : seldom
# 2022 : provided
# 2023 : william
# 2024 : elder
# 2025 : limit
# 2026 : ratcliff
# 2027 : tree
# 2028 : dignity
# 2029 : saints
# 2030 : rail
# 2031 : cover
# 2032 : beauteous
# 2033 : salisbury
# 2034 : cheerly
# 2035 : axe
# 2036 : bird
# 2037 : parting
# 2038 : tall
# 2039 : household
# 2040 : redress
# 2041 : yields
# 2042 : thieves
# 2043 : sire
# 2044 : profit
# 2045 : surely
# 2046 : griefs
# 2047 : forswear
# 2048 : rose
# 2049 : whate
# 2050 : feather
# 2051 : fourteen
# 2052 : lovest
# 2053 : crow
# 2054 : books
# 2055 : conceive
# 2056 : goose
# 2057 : modesty
# 2058 : study
# 2059 : monument
# 2060 : swain
# 2061 : perdita
# 2062 : tapster
# 2063 : price
# 2064 : neighbours
# 2065 : grain
# 2066 : provide
# 2067 : stale
# 2068 : offices
# 2069 : public
# 2070 : favours
# 2071 : hungry
# 2072 : petition
# 2073 : lately
# 2074 : revolt
# 2075 : lartius
# 2076 : chosen
# 2077 : modest
# 2078 : giddy
# 2079 : censure
# 2080 : merit
# 2081 : rejoice
# 2082 : renown
# 2083 : dozen
# 2084 : retire
# 2085 : hire
# 2086 : verily
# 2087 : mirth
# 2088 : mars
# 2089 : disdain
# 2090 : herd
# 2091 : shapes
# 2092 : backs
# 2093 : heels
# 2094 : fierce
# 2095 : prosperity
# 2096 : trumpet
# 2097 : officers
# 2098 : threatening
# 2099 : minded
# 2100 : shield
# 2101 : hare
# 2102 : scape
# 2103 : gladly
# 2104 : praises
# 2105 : treasure
# 2106 : wears
# 2107 : clamour
# 2108 : tired
# 2109 : visage
# 2110 : actions
# 2111 : brace
# 2112 : character
# 2113 : ambitious
# 2114 : windows
# 2115 : spoil
# 2116 : burning
# 2117 : statue
# 2118 : opposite
# 2119 : injury
# 2120 : determined
# 2121 : main
# 2122 : stretch
# 2123 : pleasing
# 2124 : tie
# 2125 : monster
# 2126 : stopp
# 2127 : jot
# 2128 : brown
# 2129 : ran
# 2130 : unworthy
# 2131 : aged
# 2132 : putting
# 2133 : choler
# 2134 : confirm
# 2135 : minds
# 2136 : ages
# 2137 : scandal
# 2138 : inquire
# 2139 : heat
# 2140 : rebellion
# 2141 : fearing
# 2142 : midnight
# 2143 : weapons
# 2144 : pronounce
# 2145 : forty
# 2146 : falling
# 2147 : rescue
# 2148 : spread
# 2149 : tush
# 2150 : bastards
# 2151 : virgin
# 2152 : laws
# 2153 : corrupt
# 2154 : knot
# 2155 : intelligence
# 2156 : meddle
# 2157 : harsh
# 2158 : mere
# 2159 : spleen
# 2160 : taking
# 2161 : clothes
# 2162 : thumb
# 2163 : term
# 2164 : defence
# 2165 : discourse
# 2166 : rain
# 2167 : executed
# 2168 : breed
# 2169 : record
# 2170 : likely
# 2171 : whereon
# 2172 : wealth
# 2173 : design
# 2174 : burnt
# 2175 : shot
# 2176 : lover
# 2177 : telling
# 2178 : conjure
# 2179 : stronger
# 2180 : trunk
# 2181 : framed
# 2182 : carried
# 2183 : snow
# 2184 : whereto
# 2185 : sooner
# 2186 : bigger
# 2187 : thereby
# 2188 : unjust
# 2189 : moves
# 2190 : joint
# 2191 : native
# 2192 : written
# 2193 : provoked
# 2194 : hung
# 2195 : breathing
# 2196 : spy
# 2197 : mew
# 2198 : secure
# 2199 : count
# 2200 : fiend
# 2201 : villains
# 2202 : lightning
# 2203 : guilt
# 2204 : executioner
# 2205 : shook
# 2206 : heavenly
# 2207 : berkeley
# 2208 : months
# 2209 : sweeter
# 2210 : prime
# 2211 : oh
# 2212 : careful
# 2213 : acquaint
# 2214 : adventure
# 2215 : jesu
# 2216 : peevish
# 2217 : deck
# 2218 : accident
# 2219 : charm
# 2220 : suspect
# 2221 : mates
# 2222 : faithful
# 2223 : dismal
# 2224 : burst
# 2225 : angel
# 2226 : toil
# 2227 : wake
# 2228 : reputation
# 2229 : butt
# 2230 : prosper
# 2231 : loath
# 2232 : deceit
# 2233 : blessing
# 2234 : mistrust
# 2235 : grew
# 2236 : tooth
# 2237 : shrewd
# 2238 : unfold
# 2239 : goods
# 2240 : coronation
# 2241 : weapon
# 2242 : descent
# 2243 : falls
# 2244 : royalty
# 2245 : shrift
# 2246 : enforced
# 2247 : servants
# 2248 : affords
# 2249 : lower
# 2250 : troops
# 2251 : pitch
# 2252 : depose
# 2253 : metal
# 2254 : takest
# 2255 : sullen
# 2256 : suddenly
# 2257 : tempt
# 2258 : burns
# 2259 : flattering
# 2260 : caitiff
# 2261 : torture
# 2262 : compare
# 2263 : alliance
# 2264 : wander
# 2265 : proclamation
# 2266 : surrey
# 2267 : shadows
# 2268 : dwell
# 2269 : rear
# 2270 : ward
# 2271 : boldly
# 2272 : frowns
# 2273 : appeal
# 2274 : immortal
# 2275 : trespass
# 2276 : marshal
# 2277 : civil
# 2278 : solemn
# 2279 : sepulchre
# 2280 : inch
# 2281 : ride
# 2282 : esteem
# 2283 : birds
# 2284 : bushy
# 2285 : supply
# 2286 : grandsire
# 2287 : succession
# 2288 : prick
# 2289 : despised
# 2290 : joints
# 2291 : sting
# 2292 : beshrew
# 2293 : sooth
# 2294 : borrow
# 2295 : mischance
# 2296 : rapier
# 2297 : sitting
# 2298 : madness
# 2299 : wisely
# 2300 : thirty
# 2301 : senses
# 2302 : song
# 2303 : laurence
# 2304 : mightst
# 2305 : bridegroom
# 2306 : waves
# 2307 : escape
# 2308 : paid
# 2309 : fardel
# 2310 : mystery
# 2311 : habit
# 2312 : mariana
# 2313 : cambio
# 2314 : chief
# 2315 : object
# 2316 : bread
# 2317 : piercing
# 2318 : members
# 2319 : discontented
# 2320 : mutinous
# 2321 : petty
# 2322 : helps
# 2323 : bestow
# 2324 : touching
# 2325 : lions
# 2326 : seeking
# 2327 : presume
# 2328 : parties
# 2329 : liking
# 2330 : shoes
# 2331 : cowardly
# 2332 : troop
# 2333 : caps
# 2334 : towns
# 2335 : entreaties
# 2336 : proved
# 2337 : looked
# 2338 : disease
# 2339 : infect
# 2340 : senseless
# 2341 : grim
# 2342 : wore
# 2343 : goddess
# 2344 : charges
# 2345 : couldst
# 2346 : nuptial
# 2347 : warriors
# 2348 : bands
# 2349 : dearer
# 2350 : inclined
# 2351 : condemned
# 2352 : fully
# 2353 : grieves
# 2354 : profane
# 2355 : safely
# 2356 : repose
# 2357 : gifts
# 2358 : pace
# 2359 : estimation
# 2360 : earthly
# 2361 : cap
# 2362 : wanting
# 2363 : smother
# 2364 : shown
# 2365 : commit
# 2366 : kisses
# 2367 : wills
# 2368 : destruction
# 2369 : affect
# 2370 : courteous
# 2371 : scratch
# 2372 : ought
# 2373 : also
# 2374 : twould
# 2375 : tricks
# 2376 : behavior
# 2377 : alms
# 2378 : notice
# 2379 : instantly
# 2380 : stock
# 2381 : harp
# 2382 : retired
# 2383 : falsely
# 2384 : beggars
# 2385 : horn
# 2386 : accusation
# 2387 : ope
# 2388 : conclude
# 2389 : integrity
# 2390 : merely
# 2391 : process
# 2392 : stout
# 2393 : dst
# 2394 : mildly
# 2395 : conquer
# 2396 : temples
# 2397 : injurious
# 2398 : lying
# 2399 : cheque
# 2400 : ministers
# 2401 : sentenced
# 2402 : preserve
# 2403 : saved
# 2404 : sweat
# 2405 : sup
# 2406 : beaten
# 2407 : commands
# 2408 : waked
# 2409 : bowels
# 2410 : flood
# 2411 : revenges
# 2412 : eaten
# 2413 : middle
# 2414 : deaf
# 2415 : commonwealth
# 2416 : crying
# 2417 : sole
# 2418 : prevented
# 2419 : intended
# 2420 : varlet
# 2421 : suits
# 2422 : tomorrow
# 2423 : partner
# 2424 : whisper
# 2425 : tempted
# 2426 : bond
# 2427 : chaste
# 2428 : hangs
# 2429 : dian
# 2430 : stick
# 2431 : alter
# 2432 : bidding
# 2433 : purge
# 2434 : sold
# 2435 : infected
# 2436 : outrage
# 2437 : offences
# 2438 : stern
# 2439 : amorous
# 2440 : reach
# 2441 : figure
# 2442 : balm
# 2443 : betide
# 2444 : boldness
# 2445 : afraid
# 2446 : evils
# 2447 : devilish
# 2448 : somewhat
# 2449 : bereft
# 2450 : score
# 2451 : cost
# 2452 : advocate
# 2453 : endured
# 2454 : busy
# 2455 : rebels
# 2456 : drew
# 2457 : brat
# 2458 : violence
# 2459 : hag
# 2460 : hurl
# 2461 : reply
# 2462 : dash
# 2463 : shining
# 2464 : beams
# 2465 : cloudy
# 2466 : darkness
# 2467 : nest
# 2468 : stolen
# 2469 : befall
# 2470 : wandering
# 2471 : stranger
# 2472 : marvel
# 2473 : remorse
# 2474 : zounds
# 2475 : cherish
# 2476 : swore
# 2477 : savage
# 2478 : zeal
# 2479 : frozen
# 2480 : thin
# 2481 : shallow
# 2482 : likewise
# 2483 : stays
# 2484 : worldly
# 2485 : train
# 2486 : seated
# 2487 : hers
# 2488 : conquest
# 2489 : heavier
# 2490 : nights
# 2491 : rue
# 2492 : triumphant
# 2493 : sounded
# 2494 : ely
# 2495 : likes
# 2496 : dine
# 2497 : whit
# 2498 : bootless
# 2499 : intents
# 2500 : mildness
# 2501 : substitute
# 2502 : bitterly
# 2503 : fondly
# 2504 : speaking
# 2505 : poverty
# 2506 : amiss
# 2507 : noted
# 2508 : honey
# 2509 : stops
# 2510 : tyrannous
# 2511 : ruthless
# 2512 : beget
# 2513 : dire
# 2514 : lambs
# 2515 : skill
# 2516 : bay
# 2517 : rush
# 2518 : acquainted
# 2519 : purple
# 2520 : step
# 2521 : steps
# 2522 : soil
# 2523 : sweetly
# 2524 : blemish
# 2525 : parents
# 2526 : changing
# 2527 : ships
# 2528 : frail
# 2529 : dispersed
# 2530 : signal
# 2531 : trusty
# 2532 : troubled
# 2533 : blue
# 2534 : substance
# 2535 : departure
# 2536 : except
# 2537 : share
# 2538 : greeting
# 2539 : defy
# 2540 : mount
# 2541 : grieved
# 2542 : owes
# 2543 : dared
# 2544 : correction
# 2545 : dried
# 2546 : branch
# 2547 : lists
# 2548 : pilgrimage
# 2549 : descend
# 2550 : youthful
# 2551 : coat
# 2552 : winters
# 2553 : musicians
# 2554 : bagot
# 2555 : manage
# 2556 : furnish
# 2557 : beats
# 2558 : runs
# 2559 : wiltshire
# 2560 : ravenspurgh
# 2561 : challenge
# 2562 : pernicious
# 2563 : damn
# 2564 : felt
# 2565 : pin
# 2566 : complexion
# 2567 : wood
# 2568 : likeness
# 2569 : nimble
# 2570 : lamentable
# 2571 : silly
# 2572 : benvolio
# 2573 : fray
# 2574 : mis
# 2575 : lovers
# 2576 : agree
# 2577 : torch
# 2578 : brains
# 2579 : fingers
# 2580 : courtier
# 2581 : henceforth
# 2582 : maiden
# 2583 : satisfaction
# 2584 : ghostly
# 2585 : homely
# 2586 : dido
# 2587 : mar
# 2588 : merchant
# 2589 : prettiest
# 2590 : perchance
# 2591 : couple
# 2592 : ashamed
# 2593 : philosophy
# 2594 : removed
# 2595 : rate
# 2596 : shroud
# 2597 : chat
# 2598 : bliss
# 2599 : sith
# 2600 : shines
# 2601 : thick
# 2602 : dower
# 2603 : abuse
# 2604 : lad
# 2605 : leontes
# 2606 : velvet
# 2607 : antigonus
# 2608 : ale
# 2609 : escalus
# 2610 : constable
# 2611 : beef
# 2612 : minola
# 2613 : licio
# 2614 : curtis
# 2615 : caliban
# 2616 : talking
# 2617 : sufferance
# 2618 : prating
# 2619 : undo
# 2620 : suffering
# 2621 : dearth
# 2622 : cracking
# 2623 : calamity
# 2624 : venture
# 2625 : midst
# 2626 : counsellor
# 2627 : steed
# 2628 : leg
# 2629 : shop
# 2630 : ice
# 2631 : rushes
# 2632 : nobility
# 2633 : thousands
# 2634 : lance
# 2635 : threw
# 2636 : noon
# 2637 : aims
# 2638 : utmost
# 2639 : jupiter
# 2640 : breasts
# 2641 : forehead
# 2642 : manifest
# 2643 : wednesday
# 2644 : speedy
# 2645 : agreed
# 2646 : summon
# 2647 : pot
# 2648 : following
# 2649 : sounds
# 2650 : leaden
# 2651 : numbers
# 2652 : page
# 2653 : confound
# 2654 : meaner
# 2655 : cat
# 2656 : asking
# 2657 : wave
# 2658 : serpent
# 2659 : fix
# 2660 : mask
# 2661 : plebeians
# 2662 : vouch
# 2663 : flatterers
# 2664 : silk
# 2665 : incensed
# 2666 : begg
# 2667 : crush
# 2668 : attended
# 2669 : complaint
# 2670 : pence
# 2671 : roaring
# 2672 : saddle
# 2673 : cheap
# 2674 : approbation
# 2675 : named
# 2676 : mothers
# 2677 : baby
# 2678 : popular
# 2679 : crept
# 2680 : showing
# 2681 : blaze
# 2682 : throng
# 2683 : gloves
# 2684 : event
# 2685 : seeks
# 2686 : displeasure
# 2687 : otherwise
# 2688 : theme
# 2689 : chiefest
# 2690 : sixteen
# 2691 : example
# 2692 : din
# 2693 : apart
# 2694 : intends
# 2695 : multitude
# 2696 : compass
# 2697 : nod
# 2698 : error
# 2699 : peer
# 2700 : admit
# 2701 : chose
# 2702 : certainly
# 2703 : downright
# 2704 : childish
# 2705 : springs
# 2706 : beside
# 2707 : hazard
# 2708 : antium
# 2709 : nobleness
# 2710 : tribune
# 2711 : rank
# 2712 : scatter
# 2713 : sought
# 2714 : lenity
# 2715 : confusion
# 2716 : recompense
# 2717 : crows
# 2718 : omit
# 2719 : lick
# 2720 : sides
# 2721 : roof
# 2722 : tarpeian
# 2723 : manhood
# 2724 : neptune
# 2725 : killing
# 2726 : tiger
# 2727 : meal
# 2728 : apt
# 2729 : safeguard
# 2730 : learned
# 2731 : forsooth
# 2732 : thereto
# 2733 : discharge
# 2734 : glasses
# 2735 : churchyard
# 2736 : beating
# 2737 : prate
# 2738 : steep
# 2739 : pent
# 2740 : instant
# 2741 : drift
# 2742 : load
# 2743 : vast
# 2744 : approved
# 2745 : volscian
# 2746 : ended
# 2747 : breaking
# 2748 : fallen
# 2749 : readiness
# 2750 : feasts
# 2751 : entrance
# 2752 : marvellous
# 2753 : kites
# 2754 : torn
# 2755 : extreme
# 2756 : revengeful
# 2757 : cloud
# 2758 : wedded
# 2759 : entreaty
# 2760 : rust
# 2761 : happier
# 2762 : lamentation
# 2763 : confidence
# 2764 : occupation
# 2765 : resist
# 2766 : fights
# 2767 : moving
# 2768 : rack
# 2769 : unkindness
# 2770 : aspect
# 2771 : flow
# 2772 : recreant
# 2773 : tenderness
# 2774 : requires
# 2775 : reconcile
# 2776 : stocks
# 2777 : longs
# 2778 : stead
# 2779 : eight
# 2780 : stol
# 2781 : cur
# 2782 : discontent
# 2783 : wrinkled
# 2784 : lute
# 2785 : drunken
# 2786 : prophecy
# 2787 : armed
# 2788 : waits
# 2789 : meantime
# 2790 : brotherhood
# 2791 : amends
# 2792 : ashes
# 2793 : pour
# 2794 : toads
# 2795 : hopeful
# 2796 : weight
# 2797 : heinous
# 2798 : pattern
# 2799 : madest
# 2800 : wonderful
# 2801 : devils
# 2802 : angels
# 2803 : circumstance
# 2804 : murderous
# 2805 : guiltless
# 2806 : shoulders
# 2807 : nails
# 2808 : wet
# 2809 : fee
# 2810 : designs
# 2811 : moiety
# 2812 : yon
# 2813 : shine
# 2814 : likelihood
# 2815 : lewd
# 2816 : became
# 2817 : imprison
# 2818 : disgraced
# 2819 : height
# 2820 : worser
# 2821 : alban
# 2822 : forsake
# 2823 : witch
# 2824 : scorns
# 2825 : reported
# 2826 : worm
# 2827 : livest
# 2828 : loathed
# 2829 : flourish
# 2830 : spider
# 2831 : frantic
# 2832 : lunatic
# 2833 : shade
# 2834 : eternal
# 2835 : split
# 2836 : burgundy
# 2837 : cabin
# 2838 : pearl
# 2839 : secrets
# 2840 : awaked
# 2841 : aloud
# 2842 : perjury
# 2843 : perjured
# 2844 : breaks
# 2845 : inward
# 2846 : imagination
# 2847 : signify
# 2848 : blushing
# 2849 : tail
# 2850 : threaten
# 2851 : damnable
# 2852 : sacrament
# 2853 : blade
# 2854 : hole
# 2855 : league
# 2856 : tardy
# 2857 : lap
# 2858 : proudest
# 2859 : wring
# 2860 : cousins
# 2861 : winged
# 2862 : watery
# 2863 : prophet
# 2864 : direction
# 2865 : enrich
# 2866 : storms
# 2867 : boisterous
# 2868 : growth
# 2869 : apace
# 2870 : vaughan
# 2871 : seized
# 2872 : insulting
# 2873 : ceremonious
# 2874 : ape
# 2875 : murdered
# 2876 : councils
# 2877 : commends
# 2878 : bar
# 2879 : rode
# 2880 : loyalty
# 2881 : herein
# 2882 : neglect
# 2883 : stumble
# 2884 : mast
# 2885 : ignoble
# 2886 : persons
# 2887 : begot
# 2888 : orator
# 2889 : privy
# 2890 : scotland
# 2891 : knocks
# 2892 : bent
# 2893 : matters
# 2894 : visitation
# 2895 : leaving
# 2896 : lowly
# 2897 : revenue
# 2898 : considered
# 2899 : consequence
# 2900 : roses
# 2901 : wing
# 2902 : airy
# 2903 : bending
# 2904 : ned
# 2905 : level
# 2906 : lasting
# 2907 : worms
# 2908 : wronged
# 2909 : coast
# 2910 : flock
# 2911 : brittany
# 2912 : landed
# 2913 : injustice
# 2914 : moody
# 2915 : usurping
# 2916 : model
# 2917 : lights
# 2918 : sweetest
# 2919 : fat
# 2920 : ransom
# 2921 : braved
# 2922 : sadly
# 2923 : stomach
# 2924 : spurs
# 2925 : setting
# 2926 : treasons
# 2927 : harbour
# 2928 : misfortune
# 2929 : companion
# 2930 : knight
# 2931 : falcon
# 2932 : draws
# 2933 : liberal
# 2934 : vanity
# 2935 : diest
# 2936 : careless
# 2937 : royalties
# 2938 : afore
# 2939 : livery
# 2940 : allegiance
# 2941 : moe
# 2942 : causes
# 2943 : eyed
# 2944 : midwife
# 2945 : evermore
# 2946 : leap
# 2947 : possession
# 2948 : plays
# 2949 : murders
# 2950 : tops
# 2951 : pomp
# 2952 : dim
# 2953 : swears
# 2954 : lodge
# 2955 : kinsmen
# 2956 : unruly
# 2957 : broad
# 2958 : dress
# 2959 : venice
# 2960 : beseeming
# 2961 : climate
# 2962 : procure
# 2963 : tutor
# 2964 : drinking
# 2965 : wink
# 2966 : troy
# 2967 : folks
# 2968 : contents
# 2969 : lief
# 2970 : narrow
# 2971 : forgiveness
# 2972 : breeding
# 2973 : minutes
# 2974 : push
# 2975 : window
# 2976 : pursued
# 2977 : sadness
# 2978 : cupid
# 2979 : yard
# 2980 : trow
# 2981 : guests
# 2982 : burden
# 2983 : game
# 2984 : smallest
# 2985 : closed
# 2986 : whispering
# 2987 : smell
# 2988 : pilot
# 2989 : afeard
# 2990 : rests
# 2991 : cords
# 2992 : hill
# 2993 : confessor
# 2994 : robes
# 2995 : affliction
# 2996 : array
# 2997 : learning
# 2998 : sings
# 2999 : dram
# 3000 : bridal
# 3001 : cook
# 3002 : keys
# 3003 : whoreson
# 3004 : settled
# 3005 : wolves
# 3006 : concerns
# 3007 : sufficient
# 3008 : pursue
# 3009 : neat
# 3010 : pinch
# 3011 : amain
# 3012 : nigh
# 3013 : bush
# 3014 : eldest
# 3015 : innocence
# 3016 : softly
# 3017 : errand
# 3018 : delicate
# 3019 : wenches
# 3020 : fifteen
# 3021 : heigh
# 3022 : shearing
# 3023 : pedlar
# 3024 : hangman
# 3025 : isabella
# 3026 : whipt
# 3027 : carthage
# 3028 : musician
# 3029 : sunday
# 3030 : mustard
# 3031 : ariel
# 3032 : sycorax
# 3033 : tunis
# 3034 : famish
# 3035 : thirst
# 3036 : especially
# 3037 : pays
# 3038 : tire
# 3039 : repetition
# 3040 : link
# 3041 : impediment
# 3042 : transported
# 3043 : statutes
# 3044 : gulf
# 3045 : lungs
# 3046 : replied
# 3047 : inferior
# 3048 : counsels
# 3049 : digest
# 3050 : weal
# 3051 : toe
# 3052 : rats
# 3053 : coal
# 3054 : minute
# 3055 : quarter
# 3056 : vent
# 3057 : musty
# 3058 : taunts
# 3059 : devour
# 3060 : insolence
# 3061 : rob
# 3062 : rumour
# 3063 : veil
# 3064 : shorten
# 3065 : afoot
# 3066 : comfortable
# 3067 : picture
# 3068 : returned
# 3069 : surfeit
# 3070 : harvest
# 3071 : hector
# 3072 : ladyship
# 3073 : doors
# 3074 : sensible
# 3075 : abhorr
# 3076 : terrible
# 3077 : bleed
# 3078 : thankful
# 3079 : issued
# 3080 : wheel
# 3081 : miles
# 3082 : mouse
# 3083 : budge
# 3084 : rascals
# 3085 : antiates
# 3086 : battles
# 3087 : advanced
# 3088 : frighted
# 3089 : dined
# 3090 : value
# 3091 : render
# 3092 : bribe
# 3093 : foil
# 3094 : host
# 3095 : freedom
# 3096 : craft
# 3097 : delivered
# 3098 : controversy
# 3099 : necessary
# 3100 : beastly
# 3101 : nobler
# 3102 : tonight
# 3103 : physician
# 3104 : pocket
# 3105 : possessed
# 3106 : doubly
# 3107 : expedition
# 3108 : widows
# 3109 : welcomes
# 3110 : phoebus
# 3111 : whatsoever
# 3112 : slily
# 3113 : humility
# 3114 : worthily
# 3115 : degrees
# 3116 : reproof
# 3117 : rebuke
# 3118 : heal
# 3119 : idly
# 3120 : limbs
# 3121 : meed
# 3122 : stem
# 3123 : destiny
# 3124 : quicken
# 3125 : bate
# 3126 : scars
# 3127 : require
# 3128 : proceedings
# 3129 : headed
# 3130 : bald
# 3131 : carries
# 3132 : divines
# 3133 : permit
# 3134 : mockery
# 3135 : tried
# 3136 : easily
# 3137 : solicit
# 3138 : sued
# 3139 : safer
# 3140 : apprehension
# 3141 : mutiny
# 3142 : stream
# 3143 : caused
# 3144 : composition
# 3145 : gentler
# 3146 : nourish
# 3147 : sow
# 3148 : greece
# 3149 : supreme
# 3150 : gap
# 3151 : whoever
# 3152 : unborn
# 3153 : demands
# 3154 : debase
# 3155 : locks
# 3156 : barr
# 3157 : physic
# 3158 : aediles
# 3159 : attach
# 3160 : flat
# 3161 : poisonous
# 3162 : naught
# 3163 : rend
# 3164 : cloth
# 3165 : marr
# 3166 : thrown
# 3167 : pounds
# 3168 : sack
# 3169 : created
# 3170 : disposed
# 3171 : dissemble
# 3172 : required
# 3173 : fawn
# 3174 : mould
# 3175 : baseness
# 3176 : prerogative
# 3177 : temperance
# 3178 : volume
# 3179 : fold
# 3180 : sat
# 3181 : millions
# 3182 : capital
# 3183 : extremest
# 3184 : loins
# 3185 : fan
# 3186 : chances
# 3187 : pestilence
# 3188 : hercules
# 3189 : lightly
# 3190 : dragon
# 3191 : requite
# 3192 : posterity
# 3193 : division
# 3194 : flame
# 3195 : fortunate
# 3196 : warning
# 3197 : bosoms
# 3198 : porter
# 3199 : function
# 3200 : canopy
# 3201 : dangers
# 3202 : truer
# 3203 : bestride
# 3204 : nightly
# 3205 : turned
# 3206 : assault
# 3207 : thwack
# 3208 : bottom
# 3209 : crest
# 3210 : revel
# 3211 : stirring
# 3212 : sleepy
# 3213 : rising
# 3214 : remedies
# 3215 : assistance
# 3216 : melt
# 3217 : noses
# 3218 : butchers
# 3219 : mellow
# 3220 : incapable
# 3221 : witchcraft
# 3222 : solely
# 3223 : achieve
# 3224 : commanding
# 3225 : spices
# 3226 : coals
# 3227 : distress
# 3228 : gaoler
# 3229 : faintly
# 3230 : acts
# 3231 : bowl
# 3232 : liar
# 3233 : front
# 3234 : swoon
# 3235 : hourly
# 3236 : familiar
# 3237 : keeping
# 3238 : admitted
# 3239 : latest
# 3240 : doves
# 3241 : actor
# 3242 : impression
# 3243 : flint
# 3244 : murdering
# 3245 : frost
# 3246 : temple
# 3247 : raiment
# 3248 : comforts
# 3249 : palm
# 3250 : tend
# 3251 : uncertain
# 3252 : graces
# 3253 : spurn
# 3254 : compassion
# 3255 : built
# 3256 : throats
# 3257 : milk
# 3258 : hurried
# 3259 : plants
# 3260 : stooping
# 3261 : pronounced
# 3262 : yielding
# 3263 : lads
# 3264 : killed
# 3265 : herald
# 3266 : impatience
# 3267 : lour
# 3268 : victorious
# 3269 : mounting
# 3270 : shaped
# 3271 : halt
# 3272 : g
# 3273 : plucks
# 3274 : chamberlain
# 3275 : brakenbury
# 3276 : path
# 3277 : weighty
# 3278 : marrying
# 3279 : key
# 3280 : anne
# 3281 : direful
# 3282 : spiders
# 3283 : ugly
# 3284 : higher
# 3285 : dwells
# 3286 : gape
# 3287 : blessings
# 3288 : perfection
# 3289 : fouler
# 3290 : slanderous
# 3291 : unfit
# 3292 : moan
# 3293 : boon
# 3294 : tewksbury
# 3295 : bought
# 3296 : recover
# 3297 : notwithstanding
# 3298 : cheerfully
# 3299 : deceive
# 3300 : gather
# 3301 : spilt
# 3302 : altogether
# 3303 : quake
# 3304 : unlook
# 3305 : sugar
# 3306 : befal
# 3307 : conclusion
# 3308 : allies
# 3309 : villany
# 3310 : hardy
# 3311 : skulls
# 3312 : hideous
# 3313 : glories
# 3314 : sleeps
# 3315 : resolute
# 3316 : fills
# 3317 : chop
# 3318 : unlawful
# 3319 : redemption
# 3320 : christ
# 3321 : vassal
# 3322 : publicly
# 3323 : relent
# 3324 : interchange
# 3325 : cordial
# 3326 : heap
# 3327 : lodged
# 3328 : nearer
# 3329 : hinder
# 3330 : branches
# 3331 : sap
# 3332 : plaints
# 3333 : dolour
# 3334 : knit
# 3335 : troublous
# 3336 : swell
# 3337 : biting
# 3338 : downfall
# 3339 : preposterous
# 3340 : build
# 3341 : conqueror
# 3342 : divided
# 3343 : earldom
# 3344 : shun
# 3345 : pursuit
# 3346 : upright
# 3347 : jocund
# 3348 : consorted
# 3349 : strumpet
# 3350 : helm
# 3351 : prophesy
# 3352 : straw
# 3353 : harmless
# 3354 : covert
# 3355 : shelter
# 3356 : lustful
# 3357 : appeared
# 3358 : device
# 3359 : mum
# 3360 : trifles
# 3361 : hall
# 3362 : wonders
# 3363 : ornaments
# 3364 : ambition
# 3365 : nice
# 3366 : waning
# 3367 : distressed
# 3368 : corruption
# 3369 : derived
# 3370 : lieutenant
# 3371 : looker
# 3372 : queens
# 3373 : lace
# 3374 : counted
# 3375 : captive
# 3376 : ragged
# 3377 : sayest
# 3378 : witted
# 3379 : melting
# 3380 : elizabeth
# 3381 : welshmen
# 3382 : levied
# 3383 : confines
# 3384 : sweets
# 3385 : miseries
# 3386 : entrails
# 3387 : loose
# 3388 : anchor
# 3389 : imperial
# 3390 : date
# 3391 : thereon
# 3392 : riches
# 3393 : aspiring
# 3394 : rebel
# 3395 : believed
# 3396 : avoided
# 3397 : ashore
# 3398 : levy
# 3399 : advertised
# 3400 : songs
# 3401 : pembroke
# 3402 : resort
# 3403 : walter
# 3404 : crew
# 3405 : underneath
# 3406 : fruitful
# 3407 : shrink
# 3408 : creatures
# 3409 : tents
# 3410 : car
# 3411 : ink
# 3412 : cave
# 3413 : forces
# 3414 : chastisement
# 3415 : afflict
# 3416 : praised
# 3417 : hears
# 3418 : treachery
# 3419 : eager
# 3420 : boast
# 3421 : calais
# 3422 : impeach
# 3423 : cowardice
# 3424 : coventry
# 3425 : rouse
# 3426 : chains
# 3427 : bondage
# 3428 : dancing
# 3429 : strict
# 3430 : highway
# 3431 : oppression
# 3432 : added
# 3433 : ourself
# 3434 : tribute
# 3435 : showers
# 3436 : paradise
# 3437 : siege
# 3438 : befits
# 3439 : roundly
# 3440 : mongst
# 3441 : bankrupt
# 3442 : plate
# 3443 : homage
# 3444 : events
# 3445 : create
# 3446 : heaviness
# 3447 : percy
# 3448 : staff
# 3449 : woeful
# 3450 : dispose
# 3451 : uneven
# 3452 : beguiled
# 3453 : bounty
# 3454 : peaceful
# 3455 : divorce
# 3456 : injuries
# 3457 : eating
# 3458 : forest
# 3459 : greetings
# 3460 : unseen
# 3461 : blot
# 3462 : female
# 3463 : antic
# 3464 : brass
# 3465 : follies
# 3466 : northern
# 3467 : pine
# 3468 : royally
# 3469 : tenderly
# 3470 : bone
# 3471 : turning
# 3472 : scarlet
# 3473 : phaethon
# 3474 : shriek
# 3475 : disorder
# 3476 : fruits
# 3477 : eve
# 3478 : longest
# 3479 : arrest
# 3480 : sunshine
# 3481 : lecture
# 3482 : beguile
# 3483 : moral
# 3484 : obtain
# 3485 : pitied
# 3486 : triumphs
# 3487 : conceal
# 3488 : serious
# 3489 : bell
# 3490 : groom
# 3491 : gregory
# 3492 : capulets
# 3493 : lightness
# 3494 : coz
# 3495 : reckoning
# 3496 : heel
# 3497 : tailor
# 3498 : backward
# 3499 : lends
# 3500 : curious
# 3501 : candle
# 3502 : hazel
# 3503 : inconstant
# 3504 : dainty
# 3505 : solemnity
# 3506 : saucy
# 3507 : banquet
# 3508 : madman
# 3509 : changes
# 3510 : drunkard
# 3511 : confession
# 3512 : pox
# 3513 : hoar
# 3514 : nobleman
# 3515 : delights
# 3516 : loathsome
# 3517 : street
# 3518 : consort
# 3519 : discords
# 3520 : coldly
# 3521 : sped
# 3522 : raven
# 3523 : festival
# 3524 : impatient
# 3525 : beautiful
# 3526 : blister
# 3527 : monarch
# 3528 : merciful
# 3529 : mountain
# 3530 : ebb
# 3531 : raging
# 3532 : baggage
# 3533 : acknowledge
# 3534 : week
# 3535 : extremes
# 3536 : headstrong
# 3537 : madly
# 3538 : revive
# 3539 : merriment
# 3540 : pate
# 3541 : import
# 3542 : whistle
# 3543 : cram
# ...
# 10193 : images
# 10194 : extracting
# 10195 : tub
# 10196 : unshunned
# 10197 : antiquity
# 10198 : bridget
# 10199 : wheresoever
# 10200 : extirp
# 10201 : spawned
# 10202 : urine
# 10203 : generative
# 10204 : nursing
# 10205 : detected
# 10206 : ducat
# 10207 : clack
# 10208 : withdrawing
# 10209 : locked
# 10210 : superficial
# 10211 : unweighing
# 10212 : helmed
# 10213 : testimonied
# 10214 : bringings
# 10215 : statesman
# 10216 : unskilfully
# 10217 : darkened
# 10218 : unhurtful
# 10219 : tundish
# 10220 : ungenitured
# 10221 : agent
# 10222 : sparrows
# 10223 : lecherous
# 10224 : untrussing
# 10225 : fridays
# 10226 : wounding
# 10227 : whitest
# 10228 : keepdown
# 10229 : altered
# 10230 : holiness
# 10231 : novelty
# 10232 : societies
# 10233 : fellowships
# 10234 : accurst
# 10235 : contended
# 10236 : professed
# 10237 : sinister
# 10238 : humbles
# 10239 : determination
# 10240 : discredited
# 10241 : straitness
# 10242 : striking
# 10243 : betrothed
# 10244 : exacting
# 10245 : contracting
# 10246 : inquired
# 10247 : constantly
# 10248 : circummured
# 10249 : planched
# 10250 : precept
# 10251 : concerning
# 10252 : observance
# 10253 : vaporous
# 10254 : contrarious
# 10255 : quests
# 10256 : escapes
# 10257 : snatches
# 10258 : helper
# 10259 : unpitied
# 10260 : discredit
# 10261 : oftener
# 10262 : wholesomest
# 10263 : spirts
# 10264 : envelope
# 10265 : curfew
# 10266 : rung
# 10267 : corrects
# 10268 : steeled
# 10269 : unsisting
# 10270 : dawning
# 10271 : awakens
# 10272 : bohemian
# 10273 : un
# 10274 : reprieves
# 10275 : undoubtful
# 10276 : penitently
# 10277 : touched
# 10278 : dreadfully
# 10279 : entirely
# 10280 : showed
# 10281 : constancy
# 10282 : beguiles
# 10283 : respite
# 10284 : delaying
# 10285 : limited
# 10286 : disguiser
# 10287 : shave
# 10288 : bared
# 10289 : signet
# 10290 : unfolding
# 10291 : difficulties
# 10292 : absolutely
# 10293 : dawn
# 10294 : commodity
# 10295 : ninescore
# 10296 : caper
# 10297 : mercer
# 10298 : peach
# 10299 : satin
# 10300 : peaches
# 10301 : dizy
# 10302 : copperspur
# 10303 : pudding
# 10304 : forthlight
# 10305 : tilter
# 10306 : shooty
# 10307 : traveller
# 10308 : rustle
# 10309 : sounder
# 10310 : billets
# 10311 : gravel
# 10312 : unmeet
# 10313 : reprobate
# 10314 : provides
# 10315 : journal
# 10316 : dependant
# 10317 : injunctions
# 10318 : consecrated
# 10319 : fount
# 10320 : gradation
# 10321 : balanced
# 10322 : convent
# 10323 : pervert
# 10324 : woodman
# 10325 : burr
# 10326 : disvouched
# 10327 : distracted
# 10328 : redeliver
# 10329 : exhibit
# 10330 : devices
# 10331 : unshapes
# 10332 : unpregnant
# 10333 : deflower
# 10334 : eminent
# 10335 : breather
# 10336 : riotous
# 10337 : valentinus
# 10338 : rowland
# 10339 : crassus
# 10340 : speeded
# 10341 : varrius
# 10342 : generous
# 10343 : gravest
# 10344 : hent
# 10345 : hearty
# 10346 : inquiry
# 10347 : forerunning
# 10348 : bonds
# 10349 : wards
# 10350 : forted
# 10351 : razure
# 10352 : courtesies
# 10353 : supporters
# 10354 : throwing
# 10355 : reveal
# 10356 : adulterous
# 10357 : hypocrite
# 10358 : violator
# 10359 : believest
# 10360 : dressings
# 10361 : characts
# 10362 : badness
# 10363 : oddest
# 10364 : dependency
# 10365 : inequality
# 10366 : refell
# 10367 : concupiscible
# 10368 : intemperate
# 10369 : release
# 10370 : debatement
# 10371 : sisterly
# 10372 : confutes
# 10373 : surfeiting
# 10374 : knowist
# 10375 : vehemency
# 10376 : unbelieved
# 10377 : blasting
# 10378 : meddling
# 10379 : retirement
# 10380 : swinged
# 10381 : ungot
# 10382 : temporary
# 10383 : meddler
# 10384 : vouches
# 10385 : misreport
# 10386 : villanously
# 10387 : whensoever
# 10388 : vulgarly
# 10389 : disproved
# 10390 : impartial
# 10391 : accuses
# 10392 : unmask
# 10393 : sworest
# 10394 : belock
# 10395 : carnally
# 10396 : proportions
# 10397 : disvalued
# 10398 : levity
# 10399 : tuesday
# 10400 : confixed
# 10401 : informal
# 10402 : mightier
# 10403 : member
# 10404 : testimonies
# 10405 : slanderers
# 10406 : cucullus
# 10407 : facit
# 10408 : monachum
# 10409 : retort
# 10410 : unreverend
# 10411 : touse
# 10412 : provincial
# 10413 : boil
# 10414 : stew
# 10415 : countenanced
# 10416 : barber
# 10417 : notedly
# 10418 : fleshmonger
# 10419 : treasonable
# 10420 : bolts
# 10421 : giglots
# 10422 : resists
# 10423 : foh
# 10424 : pated
# 10425 : hooded
# 10426 : sneak
# 10427 : undiscernible
# 10428 : immediate
# 10429 : sequent
# 10430 : consummate
# 10431 : advertising
# 10432 : labouring
# 10433 : remonstrance
# 10434 : celerity
# 10435 : approaching
# 10436 : defended
# 10437 : dependent
# 10438 : imputation
# 10439 : confiscation
# 10440 : instate
# 10441 : definitive
# 10442 : paved
# 10443 : ertake
# 10444 : unprofitable
# 10445 : bethought
# 10446 : pressing
# 10447 : slandering
# 10448 : shill
# 10449 : pheeze
# 10450 : slys
# 10451 : chronicles
# 10452 : paucas
# 10453 : pallabris
# 10454 : sessa
# 10455 : jeronimy
# 10456 : merriman
# 10457 : emboss
# 10458 : clowder
# 10459 : coldest
# 10460 : belman
# 10461 : merest
# 10462 : wrapp
# 10463 : delicious
# 10464 : dulcet
# 10465 : submissive
# 10466 : basin
# 10467 : bestrew
# 10468 : ewer
# 10469 : diaper
# 10470 : husbanded
# 10471 : aptly
# 10472 : naturally
# 10473 : soto
# 10474 : modesties
# 10475 : eyeing
# 10476 : buttery
# 10477 : barthol
# 10478 : obeisance
# 10479 : tempting
# 10480 : overjoy
# 10481 : onion
# 10482 : drank
# 10483 : christopher
# 10484 : burtonheath
# 10485 : cardmaker
# 10486 : transmutation
# 10487 : marian
# 10488 : wincot
# 10489 : lyingest
# 10490 : bestraught
# 10491 : lunacy
# 10492 : abject
# 10493 : couch
# 10494 : semiramis
# 10495 : trapp
# 10496 : harness
# 10497 : studded
# 10498 : hawking
# 10499 : hawks
# 10500 : echoes
# 10501 : stags
# 10502 : fleeter
# 10503 : pictures
# 10504 : adonis
# 10505 : io
# 10506 : daphne
# 10507 : roaming
# 10508 : scratching
# 10509 : workmanly
# 10510 : mightiness
# 10511 : fay
# 10512 : leet
# 10513 : cicely
# 10514 : naps
# 10515 : turph
# 10516 : pimpernell
# 10517 : thanked
# 10518 : al
# 10519 : ce
# 10520 : joan
# 10521 : undress
# 10522 : heating
# 10523 : comedy
# 10524 : comondy
# 10525 : christmas
# 10526 : gambold
# 10527 : nursery
# 10528 : lombardy
# 10529 : institute
# 10530 : bentivolii
# 10531 : treats
# 10532 : plash
# 10533 : plunge
# 10534 : satiety
# 10535 : perdonato
# 10536 : stoics
# 10537 : devote
# 10538 : aristotle
# 10539 : balk
# 10540 : rhetoric
# 10541 : poesy
# 10542 : metaphysics
# 10543 : gramercies
# 10544 : comb
# 10545 : noddle
# 10546 : legg
# 10547 : sobriety
# 10548 : displease
# 10549 : peat
# 10550 : minerva
# 10551 : penance
# 10552 : taketh
# 10553 : brooked
# 10554 : bianco
# 10555 : apples
# 10556 : maintained
# 10557 : fastest
# 10558 : gets
# 10559 : anna
# 10560 : redime
# 10561 : te
# 10562 : captum
# 10563 : quam
# 10564 : queas
# 10565 : minimo
# 10566 : longly
# 10567 : agenor
# 10568 : cretan
# 10569 : strand
# 10570 : trance
# 10571 : inventions
# 10572 : basta
# 10573 : florentine
# 10574 : serviceable
# 10575 : rebused
# 10576 : quarrelsome
# 10577 : sol
# 10578 : con
# 10579 : tutto
# 10580 : il
# 10581 : cuore
# 10582 : trovato
# 10583 : nostra
# 10584 : casa
# 10585 : molto
# 10586 : honorato
# 10587 : signor
# 10588 : mio
# 10589 : leges
# 10590 : pip
# 10591 : knocking
# 10592 : scatters
# 10593 : maze
# 10594 : florentius
# 10595 : sibyl
# 10596 : socrates
# 10597 : xanthippe
# 10598 : removes
# 10599 : wive
# 10600 : flatly
# 10601 : aglet
# 10602 : stepp
# 10603 : board
# 10604 : disfigure
# 10605 : binaca
# 10606 : rehearsed
# 10607 : stripling
# 10608 : liberality
# 10609 : assisting
# 10610 : daunt
# 10611 : ordnance
# 10612 : artillery
# 10613 : pitched
# 10614 : larums
# 10615 : neighing
# 10616 : clang
# 10617 : chestnut
# 10618 : farmer
# 10619 : bugs
# 10620 : presumes
# 10621 : contributors
# 10622 : charging
# 10623 : whatsoe
# 10624 : chiders
# 10625 : leda
# 10626 : alcides
# 10627 : hearken
# 10628 : carouses
# 10629 : bondmaid
# 10630 : gawds
# 10631 : unbind
# 10632 : untie
# 10633 : helding
# 10634 : flouts
# 10635 : affability
# 10636 : sciences
# 10637 : baccare
# 10638 : rheims
# 10639 : greek
# 10640 : languages
# 10641 : pupils
# 10642 : asketh
# 10643 : widowhood
# 10644 : survive
# 10645 : specialties
# 10646 : covenants
# 10647 : perpetually
# 10648 : lutes
# 10649 : pillory
# 10650 : fiddler
# 10651 : twangling
# 10652 : misuse
# 10653 : volubility
# 10654 : super
# 10655 : dainties
# 10656 : consolation
# 10657 : asses
# 10658 : waspish
# 10659 : coxcomb
# 10660 : combless
# 10661 : craven
# 10662 : chafe
# 10663 : gamesome
# 10664 : askance
# 10665 : affable
# 10666 : limp
# 10667 : twig
# 10668 : hue
# 10669 : nill
# 10670 : conformable
# 10671 : fatherly
# 10672 : ruffian
# 10673 : temperate
# 10674 : grissel
# 10675 : incredible
# 10676 : protesting
# 10677 : twink
# 10678 : novices
# 10679 : meacock
# 10680 : curstest
# 10681 : mart
# 10682 : youngling
# 10683 : graybeard
# 10684 : fry
# 10685 : skipper
# 10686 : nourisheth
# 10687 : flourisheth
# 10688 : basins
# 10689 : ewers
# 10690 : lave
# 10691 : hangings
# 10692 : tyrian
# 10693 : tapestry
# 10694 : ivory
# 10695 : arras
# 10696 : counterpoints
# 10697 : canopies
# 10698 : turkey
# 10699 : boss
# 10700 : valance
# 10701 : needlework
# 10702 : pewter
# 10703 : housekeeping
# 10704 : milch
# 10705 : kine
# 10706 : pail
# 10707 : sixscore
# 10708 : oxen
# 10709 : answerable
# 10710 : marseilles
# 10711 : argosies
# 10712 : galliases
# 10713 : tight
# 10714 : galleys
# 10715 : gamester
# 10716 : crafty
# 10717 : card
# 10718 : braves
# 10719 : breeching
# 10720 : schools
# 10721 : pantaloon
# 10722 : pedascule
# 10723 : aeacides
# 10724 : ajax
# 10725 : unkindly
# 10726 : groweth
# 10727 : rudiments
# 10728 : briefer
# 10729 : pithy
# 10730 : effectual
# 10731 : ranging
# 10732 : rudesby
# 10733 : jerkin
# 10734 : breeches
# 10735 : buckled
# 10736 : laced
# 10737 : armory
# 10738 : chapeless
# 10739 : hipped
# 10740 : mothy
# 10741 : stirrups
# 10742 : glanders
# 10743 : mose
# 10744 : chine
# 10745 : lampass
# 10746 : wingdalls
# 10747 : spavins
# 10748 : yellows
# 10749 : fives
# 10750 : begnawn
# 10751 : bots
# 10752 : swayed
# 10753 : shotten
# 10754 : legged
# 10755 : chequed
# 10756 : sheeps
# 10757 : stumbling
# 10758 : repaired
# 10759 : girth
# 10760 : velure
# 10761 : studs
# 10762 : caparisoned
# 10763 : gartered
# 10764 : pricked
# 10765 : footboy
# 10766 : oftentimes
# 10767 : howsoe
# 10768 : jamy
# 10769 : gallants
# 10770 : comet
# 10771 : sadder
# 10772 : digress
# 10773 : accoutrements
# 10774 : concerneth
# 10775 : unparted
# 10776 : skills
# 10777 : narrowly
# 10778 : greybeard
# 10779 : prying
# 10780 : curster
# 10781 : gogs
# 10782 : wouns
# 10783 : trembled
# 10784 : vicar
# 10785 : ceremonies
# 10786 : carousing
# 10787 : muscadel
# 10788 : sexton
# 10789 : hungerly
# 10790 : rout
# 10791 : oats
# 10792 : jogging
# 10793 : domineer
# 10794 : carouse
# 10795 : stare
# 10796 : chattels
# 10797 : barn
# 10798 : ox
# 10799 : beset
# 10800 : matches
# 10801 : mated
# 10802 : kated
# 10803 : junkets
# 10804 : taller
# 10805 : tames
# 10806 : trimmed
# 10807 : strewed
# 10808 : cobwebs
# 10809 : fustian
# 10810 : jills
# 10811 : carpets
# 10812 : saddles
# 10813 : listening
# 10814 : imprimis
# 10815 : riding
# 10816 : crossed
# 10817 : miry
# 10818 : bemoiled
# 10819 : unexperienced
# 10820 : joseph
# 10821 : nicholas
# 10822 : sugarsop
# 10823 : sleekly
# 10824 : combed
# 10825 : brushed
# 10826 : garters
# 10827 : curtsy
# 10828 : spruce
# 10829 : alighted
# 10830 : logger
# 10831 : unpolish
# 10832 : grooms
# 10833 : malt
# 10834 : gabriel
# 10835 : pumps
# 10836 : unpink
# 10837 : ralph
# 10838 : orders
# 10839 : walked
# 10840 : spaniel
# 10841 : troilus
# 10842 : slippers
# 10843 : dresser
# 10844 : theretake
# 10845 : trenchers
# 10846 : cups
# 10847 : heedless
# 10848 : joltheads
# 10849 : unmanner
# 10850 : grumble
# 10851 : planteth
# 10852 : roasted
# 10853 : sermon
# 10854 : rails
# 10855 : politicly
# 10856 : successfully
# 10857 : undeserved
# 10858 : bolster
# 10859 : amid
# 10860 : hurly
# 10861 : curb
# 10862 : teaching
# 10863 : proceeders
# 10864 : womankind
# 10865 : disdainful
# 10866 : napping
# 10867 : teacheth
# 10868 : spied
# 10869 : mercatante
# 10870 : format
# 10871 : tripoli
# 10872 : incomparable
# 10873 : resemble
# 10874 : repute
# 10875 : spites
# 10876 : repast
# 10877 : tripe
# 10878 : deluding
# 10879 : amort
# 10880 : diligent
# 10881 : bespeak
# 10882 : porringer
# 10883 : walnut
# 10884 : shell
# 10885 : concealing
# 10886 : uttermost
# 10887 : paltry
# 10888 : likest
# 10889 : masquing
# 10890 : tart
# 10891 : snip
# 10892 : nip
# 10893 : slish
# 10894 : slash
# 10895 : flea
# 10896 : nit
# 10897 : skein
# 10898 : quantity
# 10899 : ergo
# 10900 : sew
# 10901 : skirts
# 10902 : sewed
# 10903 : darkest
# 10904 : peereth
# 10905 : eel
# 10906 : furniture
# 10907 : frolic
# 10908 : genoa
# 10909 : lodgers
# 10910 : pegasus
# 10911 : debts
# 10912 : beareth
# 10913 : shortness
# 10914 : affied
# 10915 : hearkening
# 10916 : scrivener
# 10917 : pittance
# 10918 : happened
# 10919 : expound
# 10920 : cum
# 10921 : privilegio
# 10922 : ad
# 10923 : imprimendum
# 10924 : solum
# 10925 : hearest
# 10926 : parsley
# 10927 : rabbit
# 10928 : appendix
# 10929 : moonlight
# 10930 : spangle
# 10931 : budding
# 10932 : allot
# 10933 : bedazzled
# 10934 : travellest
# 10935 : dowery
# 10936 : spouse
# 10937 : joyous
# 10938 : travellers
# 10939 : overtake
# 10940 : untoward
# 10941 : shipping
# 10942 : copatain
# 10943 : university
# 10944 : cerns
# 10945 : sailmaker
# 10946 : bergamo
# 10947 : forthcoming
# 10948 : hailed
# 10949 : eyne
# 10950 : miracles
# 10951 : wished
# 10952 : slit
# 10953 : cake
# 10954 : perils
# 10955 : overblown
# 10956 : sakes
# 10957 : catches
# 10958 : simile
# 10959 : hits
# 10960 : outright
# 10961 : hawk
# 10962 : halves
# 10963 : conferring
# 10964 : parlor
# 10965 : womanly
# 10966 : laying
# 10967 : scornful
# 10968 : glances
# 10969 : frosts
# 10970 : meads
# 10971 : whirlwinds
# 10972 : amiable
# 10973 : maintenance
# 10974 : commits
# 10975 : oweth
# 10976 : contending
# 10977 : straws
# 10978 : winner
# 10979 : yarely
# 10980 : aground
# 10981 : topsail
# 10982 : cabins
# 10983 : roarers
# 10984 : bawling
# 10985 : blasphemous
# 10986 : incharitable
# 10987 : noisemaker
# 10988 : nutshell
# 10989 : leaky
# 10990 : m
# 10991 : chapp
# 10992 : washing
# 10993 : widest
# 10994 : glut
# 10995 : acre
# 10996 : heath
# 10997 : furze
# 10998 : dashes
# 10999 : suffered
# 11000 : sunk
# 11001 : fraughting
# 11002 : provision
# 11003 : ordered
# 11004 : inquisition
# 11005 : concluding
# 11006 : tended
# 11007 : abysm
# 11008 : blessedly
# 11009 : teen
# 11010 : perfidious
# 11011 : reputed
# 11012 : heedfully
# 11013 : perfected
# 11014 : trash
# 11015 : verdure
# 11016 : dedicated
# 11017 : closeness
# 11018 : bettering
# 11019 : sans
# 11020 : lorded
# 11021 : exact
# 11022 : sinner
# 11023 : substitution
# 11024 : deafness
# 11025 : screen
# 11026 : annual
# 11027 : coronet
# 11028 : unbow
# 11029 : lieu
# 11030 : premises
# 11031 : extirpate
# 11032 : fated
# 11033 : wrings
# 11034 : impertinent
# 11035 : leagues
# 11036 : carcass
# 11037 : rigg
# 11038 : instinctively
# 11039 : hoist
# 11040 : cherubim
# 11041 : fortitude
# 11042 : undergoing
# 11043 : providence
# 11044 : linens
# 11045 : stuffs
# 11046 : steaded
# 11047 : princesses
# 11048 : vainer
# 11049 : prescience
# 11050 : zenith
# 11051 : influence
# 11052 : dulness
# 11053 : curl
# 11054 : boarded
# 11055 : beak
# 11056 : flamed
# 11057 : yards
# 11058 : bowsprit
# 11059 : lightnings
# 11060 : precursors
# 11061 : outrunning
# 11062 : plunged
# 11063 : ferdinand
# 11064 : reeds
# 11065 : sustaining
# 11066 : badest
# 11067 : cooling
# 11068 : nook
# 11069 : stow
# 11070 : mediterranean
# 11071 : flote
# 11072 : preciously
# 11073 : mistakings
# 11074 : grumblings
# 11075 : ooze
# 11076 : baked
# 11077 : manifold
# 11078 : sorceries
# 11079 : earthy
# 11080 : refusing
# 11081 : hests
# 11082 : unmitigable
# 11083 : painfully
# 11084 : freckled
# 11085 : penetrate
# 11086 : murmur
# 11087 : peg
# 11088 : knotty
# 11089 : correspondent
# 11090 : spiriting
# 11091 : invisible
# 11092 : eyeball
# 11093 : apparition
# 11094 : brush
# 11095 : stitches
# 11096 : urchins
# 11097 : honeycomb
# 11098 : bees
# 11099 : strokedst
# 11100 : berries
# 11101 : beetles
# 11102 : peopled
# 11103 : calibans
# 11104 : gabble
# 11105 : deservedly
# 11106 : setebos
# 11107 : courtsied
# 11108 : whist
# 11109 : ding
# 11110 : dong
# 11111 : ditty
# 11112 : fringed
# 11113 : strays
# 11114 : airs
# 11115 : ungently
# 11116 : muscles
# 11117 : husks
# 11118 : acorn
# 11119 : cradled
# 11120 : disarm
# 11121 : imposter
# 11122 : goodlier
# 11123 : syllable
# 11124 : porridge
# 11125 : visitor
# 11126 : entertainer
# 11127 : dollar
# 11128 : wiselier
# 11129 : spendthrift
# 11130 : uninhabitable
# 11131 : inaccessible
# 11132 : everything
# 11133 : advantageous
# 11134 : lush
# 11135 : tawny
# 11136 : misses
# 11137 : totally
# 11138 : rarity
# 11139 : vouched
# 11140 : rarities
# 11141 : drenched
# 11142 : freshness
# 11143 : glosses
# 11144 : pockets
# 11145 : claribel
# 11146 : aeneas
# 11147 : miraculous
# 11148 : sowing
# 11149 : islands
# 11150 : fished
# 11151 : surges
# 11152 : breasted
# 11153 : surge
# 11154 : bove
# 11155 : contentious
# 11156 : oar
# 11157 : basis
# 11158 : african
# 11159 : loathness
# 11160 : chirurgeonly
# 11161 : plantation
# 11162 : docks
# 11163 : mallows
# 11164 : contraries
# 11165 : forgets
# 11166 : endeavour
# 11167 : felony
# 11168 : pike
# 11169 : mong
# 11170 : excel
# 11171 : laughed
# 11172 : sphere
# 11173 : weeks
# 11174 : bat
# 11175 : fowling
# 11176 : weakly
# 11177 : drowsiness
# 11178 : possesses
# 11179 : eyelids

# %%
src_input = tensor[:,:-1]
tgt_input = tensor[:,1:]

print(src_input[0])
print(tgt_input[0])
# Out:
# [  2 143  40 933 140 591   4 124  24 110   5   3   0   0   0   0   0   0
#    0   0]
# [143  40 933 140 591   4 124  24 110   5   3   0   0   0   0   0   0   0
#    0   0]

# %% [markdown]
# # 3.corpus 텐서를 tf.data.Dataset객체로 변환

# %%
BUFFER_SIZE = len(src_input)
BATCH_SIZE = 256
steps_per_epoch = len(src_input) // BATCH_SIZE

VOCAB_SIZE = tokenizer.num_words +1

dataset = tf.data.Dataset.from_tensor_slices((src_input,tgt_input))
dataset = dataset.shuffle(BUFFER_SIZE)
dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
dataset
# Out:
# 2022-12-30 14:28:27.591928: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# <BatchDataset shapes: ((256, 20), (256, 20)), types: (tf.int32, tf.int32)>

# %% [markdown]
# # 6-5. 실습 (2) 인공지능 학습시키기

# %%
class TextGenerator(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, hidden_size):
        super().__init__()
        # Embedding 레이어, 2개의 LSTM 레이어, 1개의 Dense 레이어로 구성되어 있다.
        # Embedding 레이어는 단어 사전의 인덱스 값을 해당 인덱스 번째의 워드 벡터로 바꿔준다.
        # 이 워드 벡터는 의미 벡터 공간에서 단어의 추상적 표현으로 사용된다. 
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size) 
        self.rnn_1 = tf.keras.layers.LSTM(hidden_size, return_sequences=True)  
        self.rnn_2 = tf.keras.layers.LSTM(hidden_size, return_sequences=True)
        self.linear = tf.keras.layers.Dense(vocab_size)
        
    def call(self, x):
        out = self.embedding(x)
        out = self.rnn_1(out)
        out = self.rnn_2(out)
        out = self.linear(out)
        
        return out
# embedding size 값이 커질수록 단어의 추상적인 특징들을 더 잡아낼 수 있지만
# 그만큼 충분한 데이터가 없으면 안좋은 결과 값을 가져옵니다!   
embedding_size = 256 # 워드 벡터의 차원수를 말하며 단어가 추상적으로 표현되는 크기입니다.
hidden_size = 1024 # 모델에 얼마나 많은 일꾼을 둘 것인가? 정도로 이해하면 좋다.
model = TextGenerator(tokenizer.num_words + 1, embedding_size , hidden_size) # tokenizer.num_words에 +1인 이유는 문장에 없는 pad가 사용되었기 때문이다.

# %%
embedding_size = 256
hidden_size = 1024
model = TextGenerator(tokenizer.num_words+1, embedding_size,hidden_size)

# %%
for src_sample, tgt_sample in dataset.take(1): break
    
model(src_sample)
# Out:
# <tf.Tensor: shape=(256, 20, 7001), dtype=float32, numpy=
# array([[[-2.02200506e-04,  7.06054270e-05, -1.86313409e-04, ...,
#           5.01989387e-04,  2.44223775e-05, -4.86011326e-04],
#         [-2.83828296e-04, -9.31309842e-05, -4.01828700e-04, ...,
#           1.04830298e-03,  7.78802714e-05, -8.87074566e-04],
#         [-3.99782322e-04, -3.40607658e-05, -2.34434672e-04, ...,
#           1.23562384e-03, -9.83536593e-05, -1.25827920e-03],
#         ...,
#         [-1.11453666e-03, -4.07708460e-04, -2.08654930e-03, ...,
#          -1.69334223e-03, -1.28406857e-03, -2.07696576e-03],
#         [-1.15215522e-03, -3.97050346e-04, -2.19418434e-03, ...,
#          -1.95000065e-03, -1.23840093e-03, -2.73245410e-03],
#         [-1.18474453e-03, -4.04955936e-04, -2.25602044e-03, ...,
#          -2.17633392e-03, -1.20432116e-03, -3.36169126e-03]],
#
#        [[-2.02200506e-04,  7.06054270e-05, -1.86313409e-04, ...,
#           5.01989387e-04,  2.44223775e-05, -4.86011326e-04],
#         [-2.05405973e-04,  2.71574154e-05, -3.32516327e-04, ...,
#           6.61791186e-04, -1.33722118e-04, -2.32913546e-04],
#         [-2.65680748e-04, -1.44621838e-04, -4.03036771e-04, ...,
#           6.93714537e-04, -3.89345339e-04, -8.66675255e-05],
#         ...,
#         [-9.69256449e-04, -4.80255316e-04, -1.69214560e-03, ...,
#          -2.87084654e-03, -1.25766499e-03, -4.94352356e-03],
#         [-1.03304046e-03, -5.05059259e-04, -1.70940813e-03, ...,
#          -2.97469110e-03, -1.27248676e-03, -5.38258487e-03],
#         [-1.09899370e-03, -5.30942169e-04, -1.71138265e-03, ...,
#          -3.06024961e-03, -1.29633618e-03, -5.76514006e-03]],
#
#        [[-2.02200506e-04,  7.06054270e-05, -1.86313409e-04, ...,
#           5.01989387e-04,  2.44223775e-05, -4.86011326e-04],
#         [-3.32191557e-05,  1.46607752e-04,  4.67586942e-05, ...,
#           7.42842676e-04, -1.62990909e-05, -5.97447332e-04],
#         [-9.64022911e-05,  4.32520523e-04,  1.98077105e-04, ...,
#           9.76423675e-04, -1.24054000e-04, -5.94423851e-04],
#         ...,
#         [-1.26136246e-03,  2.09290447e-04, -1.21898833e-03, ...,
#          -1.15663465e-03, -1.00039644e-04, -1.59344508e-03],
#         [-1.22146821e-03,  1.53609988e-04, -1.39235426e-03, ...,
#          -1.60966802e-03, -8.94711120e-05, -2.17705243e-03],
#         [-1.18744932e-03,  7.79296970e-05, -1.52980490e-03, ...,
#          -1.99511531e-03, -1.06338644e-04, -2.77710077e-03]],
#
#        ...,
#
#        [[-2.02200506e-04,  7.06054270e-05, -1.86313409e-04, ...,
#           5.01989387e-04,  2.44223775e-05, -4.86011326e-04],
#         [-5.13374456e-04, -8.51811928e-05, -1.87227779e-04, ...,
#           8.63467518e-04, -1.95660003e-04, -6.57592900e-04],
#         [-5.83475630e-04, -2.05550896e-04, -2.15240696e-04, ...,
#           1.31127797e-03, -3.66401102e-04, -6.43090345e-04],
#         ...,
#         [-1.15401531e-03, -7.79592781e-04, -2.10129679e-03, ...,
#          -2.73008877e-03, -9.06607369e-04, -5.32336254e-03],
#         [-1.19372807e-03, -7.87970377e-04, -2.06177309e-03, ...,
#          -2.85683363e-03, -9.89542692e-04, -5.71909593e-03],
#         [-1.23689650e-03, -7.90424529e-04, -2.01289402e-03, ...,
#          -2.96366587e-03, -1.06965611e-03, -6.06055139e-03]],
#
#        [[-2.02200506e-04,  7.06054270e-05, -1.86313409e-04, ...,
#           5.01989387e-04,  2.44223775e-05, -4.86011326e-04],
#         [-4.34950343e-04,  1.01979196e-04, -6.33165255e-05, ...,
#           6.75268471e-04,  4.84564007e-05, -9.61292710e-04],
#         [-9.55611351e-04,  6.71586022e-05, -2.69739423e-04, ...,
#           1.06605422e-03, -8.54759855e-05, -9.09385446e-04],
#         ...,
#         [-1.43662631e-03, -9.13092343e-04, -1.76532636e-03, ...,
#          -1.50785584e-03,  2.41154630e-05, -1.52170588e-03],
#         [-1.36748631e-03, -8.05799093e-04, -1.89058506e-03, ...,
#          -1.87599950e-03, -1.55191519e-05, -2.21864856e-03],
#         [-1.30965514e-03, -7.31830427e-04, -1.98665797e-03, ...,
#          -2.18586763e-03, -7.50027830e-05, -2.90008890e-03]],
#
#        [[-2.02200506e-04,  7.06054270e-05, -1.86313409e-04, ...,
#           5.01989387e-04,  2.44223775e-05, -4.86011326e-04],
#         [-3.25975328e-04,  2.35861153e-04, -3.11245676e-04, ...,
#           1.04100374e-03, -4.30156360e-04, -6.27132657e-04],
#         [-2.14941887e-04,  2.45375995e-04, -3.87826003e-04, ...,
#           1.53989869e-03, -2.46487936e-04, -8.24350864e-04],
#         ...,
#         [-1.08082220e-03,  5.77652885e-04, -1.80286670e-03, ...,
#          -1.91067101e-03,  7.53413769e-05, -1.65601610e-03],
#         [-1.06395804e-03,  4.47498431e-04, -1.88439456e-03, ...,
#          -2.16051098e-03, -3.50602786e-05, -2.38634739e-03],
#         [-1.05881155e-03,  3.10165400e-04, -1.93751557e-03, ...,
#          -2.36844504e-03, -1.55955262e-04, -3.08199716e-03]]],
#       dtype=float32)>

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.0

# %%
model.summary()
# Out:
# Model: "text_generator_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      multiple                  1792256
# _________________________________________________________________
# lstm_2 (LSTM)                multiple                  5246976
# _________________________________________________________________
# lstm_3 (LSTM)                multiple                  8392704
# _________________________________________________________________
# dense_1 (Dense)              multiple                  7176025
# =================================================================
# Total params: 22,607,961
# Trainable params: 22,607,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam() # Adam은 현재 가장 많이 사용하는 옵티마이저이다. 자세한 내용은 차차 배운다.
loss = tf.keras.losses.SparseCategoricalCrossentropy( # 훈련 데이터의 라벨이 정수의 형태로 제공될 때 사용하는 손실함수이다.
    from_logits=True, # 기본값은 False이다. 모델에 의해 생성된 출력 값이 정규화되지 않았음을 손실 함수에 알려준다. 즉 softmax함수가 적용되지 않았다는걸 의미한다. 
    reduction='none'  # 기본값은 SUM이다. 각자 나오는 값의 반환 원할 때 None을 사용한다.
)
# 모델을 학습시키키 위한 학습과정을 설정하는 단계이다.
model.compile(optimizer=optimizer, loss=loss) # 손실함수와 훈련과정을 설정했다.
model.fit(dataset, epochs=30) # 만들어둔 데이터셋으로 모델을 학습한다. 30번 학습을 반복하겠다는 의미다.
# Out:
# Epoch 1/30
# 2022-12-30 14:28:36.003464: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# 93/93 [==============================] - 645s 7s/step - loss: 3.5929
# Epoch 2/30
# 93/93 [==============================] - 596s 6s/step - loss: 2.8305
# Epoch 3/30
# 93/93 [==============================] - 616s 7s/step - loss: 2.7513
# Epoch 4/30
# 93/93 [==============================] - 620s 7s/step - loss: 2.6622
# Epoch 5/30
# 93/93 [==============================] - 571s 6s/step - loss: 2.5982
# Epoch 6/30
# 93/93 [==============================] - 422s 5s/step - loss: 2.5407
# Epoch 7/30
# 93/93 [==============================] - 396s 4s/step - loss: 2.4859
# Epoch 8/30
# 93/93 [==============================] - 538s 6s/step - loss: 2.4386
# Epoch 9/30
# 93/93 [==============================] - 709s 8s/step - loss: 2.3972
# Epoch 10/30
# 93/93 [==============================] - 1131s 12s/step - loss: 2.3574
# Epoch 11/30
# 93/93 [==============================] - 974s 10s/step - loss: 2.3209
# Epoch 12/30
# 93/93 [==============================] - 490s 5s/step - loss: 2.2849
# Epoch 13/30
# 93/93 [==============================] - 537s 6s/step - loss: 2.2520
# Epoch 14/30
# 93/93 [==============================] - 492s 5s/step - loss: 2.2195
# Epoch 15/30
# 93/93 [==============================] - 571s 6s/step - loss: 2.1893
# Epoch 16/30
# 93/93 [==============================] - 654s 7s/step - loss: 2.1568
# Epoch 17/30
# 93/93 [==============================] - 657s 7s/step - loss: 2.1269
# Epoch 18/30
# 93/93 [==============================] - 699s 8s/step - loss: 2.0950
# Epoch 19/30
# 93/93 [==============================] - 1319s 14s/step - loss: 2.0644
# Epoch 20/30
# 93/93 [==============================] - 683s 7s/step - loss: 2.0324
# Epoch 21/30
# 93/93 [==============================] - 678s 7s/step - loss: 2.0030
# Epoch 22/30
# 93/93 [==============================] - 505s 5s/step - loss: 1.9706
# Epoch 23/30
# 93/93 [==============================] - 475s 5s/step - loss: 1.9391
# Epoch 24/30
# 93/93 [==============================] - 463s 5s/step - loss: 1.9098
# Epoch 25/30
# 93/93 [==============================] - 456s 5s/step - loss: 1.8784
# Epoch 26/30
# 93/93 [==============================] - 530s 6s/step - loss: 1.8473
# Epoch 27/30
# 93/93 [==============================] - 453s 5s/step - loss: 1.8172
# Epoch 28/30
# 93/93 [==============================] - 443s 5s/step - loss: 1.7877
# Epoch 29/30
# 93/93 [==============================] - 446s 5s/step - loss: 1.7582
# Epoch 30/30
# 93/93 [==============================] - 483s 5s/step - loss: 1.7285

# %% [markdown]
# # 6-6. 실습 (3) 잘 만들어졌는지 평가하기

# %%
#문장생성 함수 정의
#모델에게 시작 문장을 전달하면 모델이 시작 문장을 바탕으로 작문을 진행
def generate_text(model, tokenizer, init_sentence="<start>", max_len=20): #시작 문자열을 init_sentence 로 받으며 디폴트값은 <start> 를 받는다
    # 테스트를 위해서 입력받은 init_sentence도 텐서로 변환합니다
    test_input = tokenizer.texts_to_sequences([init_sentence]) #텍스트 안의 단어들을 숫자의 시퀀스의 형태로 변환
    test_tensor = tf.convert_to_tensor(test_input, dtype=tf.int64)
    end_token = tokenizer.word_index["<end>"]

    # 단어 하나씩 예측해 문장을 만듭니다
    #    1. 입력받은 문장의 텐서를 입력합니다
    #    2. 예측된 값 중 가장 높은 확률인 word index를 뽑아냅니다
    #    3. 2에서 예측된 word index를 문장 뒤에 붙입니다
    #    4. 모델이 <end>를 예측했거나, max_len에 도달했다면 문장 생성을 마칩니다 (도달 하지 못하였으면 while 루프를 돌면서 다음 단어를 예측)
    while True: #루프를 돌면서 init_sentence에 단어를 하나씩 생성성
        # 1
        predict = model(test_tensor) 
        # 2
        predict_word = tf.argmax(tf.nn.softmax(predict, axis=-1), axis=-1)[:, -1] 
        # 3 
        test_tensor = tf.concat([test_tensor, tf.expand_dims(predict_word, axis=0)], axis=-1)
        # 4 
        if predict_word.numpy()[0] == end_token: break
        if test_tensor.shape[1] >= max_len: break

    generated = ""
    # tokenizer를 이용해 word index를 단어로 하나씩 변환합니다 
    for word_index in test_tensor[0].numpy():
        generated += tokenizer.index_word[word_index] + " "

    return generated #최종적으로 모델이 생성한 문장을 반환

# %%
generate_text(model, tokenizer, init_sentence="<start> mother") # 시작문장으로 he를 넣어 문장생성 함수 실행
